# %% [markdown]
# ## Text Generation
# Using markov chains to generate text

# %%
import pandas as pd

corpus_pd = pd.read_pickle('corpus.pkl')
corpus_pd
# Out:
#                                                 transcript        full_names
# ali      Ladies and gentlemen, please welcome to the st...          Ali Wong
# anthony  Thank you. Thank you. Thank you, San Francisco...  Anthony Jeselnik
# bert     [electronic music playing] [male announcer] La...         Bill Burr
# bill     [cheers and applause] All right, thank you! Th...        Bo Burnham
# dave     Sticks & Stones is Dave Chappelle’s fifth Netf...    Dave Chappelle
# hasan    [theme music: orchestral hip-hop] [crowd roars...      Hasan Minhaj
# jim      [Car horn honks] [Audience cheering] [Announce...     Jim Jefferies
# joe      [rock music playing] [audience cheering] [anno...         Joe Rogan
# john     [organ music playing] Welcome to Radio City Mu...      John Mulaney
# louis    Intro\nFade the music out. Let’s roll. Hold th...        Louis C.K.
# mike     Wow. Hey, thank you. Thanks. Thank you, guys. ...    Mike Birbiglia
# nikki    A NETFLIX ORIGINAL COMEDY SPECIAL Thank you! T...      Nikki Glaser
# ricky    Hello. Hello! How you doing? Great. Thank you....     Ricky Gervais
# russell  -Yeah, Russell! Oi, Russell! Your mother is so...    Russell Peters

# %%
russell_text = corpus_pd.transcript.loc['russell']
russell_text[:100]
# Out:
# '-Yeah, Russell! Oi, Russell! Your mother is so fat. What the hell did you say to me? Do I look like '

# %% [markdown]
# # Build the Markov Chain
#
# The keys should be all of the words in the corpus
#
# The values should be a list of the words that follow the keys

# %%
from collections import defaultdict

def markov_chain(text):
    '''The input is a string of text and the output will be a dictionary with each word as
       a key and each value as the list of words that come after the key in the text.'''
    
    # Tokenize the text by word, though including punctuation
    words = text.split(' ')
    
    # Initialize a default dictionary to hold all of the words and next words
    m_dict = defaultdict(list)
    
    # Create a zipped list of all of the word pairs and put them in word: list of next words format
    for current_word, next_word in zip(words[0:-1], words[1:]):
        m_dict[current_word].append(next_word)

    # Convert the default dict back into a dictionary
    m_dict = dict(m_dict)
    return m_dict

# %%
russell_dict = markov_chain(russell_text)
russell_dict
# Out:
# {'-Yeah,': ['Russell!', 'bro.'],
#  'Russell!': ['Oi,', 'Your'],
#  'Oi,': ['Russell!'],
#  'Your': ['mother',
#   'mom',
#   'mom',
#   'good',
#   'first',
#   'son’s',
#   'wife?',
#   'parents'],
#  'mother': ['is'],
#  'is': ['so',
#   'in',
#   'like',
#   'a',
#   'fucking',
#   'impressive.',
#   'here.',
#   'all',
#   'more',
#   'add',
#   'gonna',
#   'inflamed',
#   'an',
#   'hiring.”',
#   'a',
#   'be',
#   'like',
#   '’cause',
#   'like',
#   'like',
#   'when',
#   'that',
#   'that?',
#   'my',
#   'my',
#   'that?',
#   'because…',
#   'just',
#   'fantastic.',
#   'in',
#   'half',
#   'literally',
#   '28.',
#   'that',
#   'what',
#   'determination…',
#   'very',
#   'very',
#   'everything',
#   'your',
#   'weird.',
#   'as',
#   'a',
#   'race-based.',
#   'I',
#   'because',
#   'the'],
#  'so': ['fat.',
#   'glad',
#   'their',
#   'scared!',
#   'much',
#   'mad,',
#   'cheap,',
#   'we',
#   'they',
#   'mad.',
#   'I’m',
#   'I',
#   'slowly.',
#   'slow',
#   'the',
#   'you',
#   'violently',
#   'hard',
#   'hard',
#   'bad.',
#   'weird,',
#   'he',
#   'you',
#   'casually.'],
#  'fat.': ['What'],
#  'What': ['the',
#   'was',
#   'instrument',
#   'fucking',
#   'is',
#   'are',
#   'is',
#   'does',
#   'the..',
#   'happened?”',
#   'are',
#   'style',
#   'the',
#   'up,'],
#  'the': ['hell',
#   'house.',
#   'pride',
#   'main',
#   'one',
#   'most',
#   'jokes',
#   'doctor',
#   'other',
#   'gynecologist.',
#   'other',
#   'three',
#   'least.',
#   'caterpillar',
#   'audience',
#   'summer',
#   'world.',
#   'dumbest',
#   'rest',
#   'mean',
#   'NBA.”',
#   'nickname',
#   '‘hood',
#   '“‘hood”',
#   'guy',
#   '‘hood',
#   'right',
#   'end',
#   'office.',
#   'doctor',
#   'right',
#   'black',
#   'store.',
#   'house.',
#   'next',
#   'chickens',
#   'line.',
#   'bad',
#   'rest',
#   'house',
#   'mall.”',
#   'ultimate',
#   'airport',
#   'airport',
#   'hell',
#   'airport?”',
#   'hell',
#   'shit',
#   'year.”',
#   'baggage',
#   'plane.”',
#   'baggage',
#   'plane.”',
#   'plane?”',
#   'plane.”',
#   'showoff.',
#   'worst',
#   '1-800',
#   'back',
#   'call',
#   'fuck',
#   'forest,',
#   'fuck',
#   'same',
#   'name',
#   'mouse',
#   'hell',
#   'way',
#   'air',
#   '400.',
#   '400.',
#   'kitchen,',
#   'phone',
#   'real',
#   'object',
#   'one',
#   'same',
#   'dinner',
#   'peas?”',
#   'funniest',
#   'world.',
#   'more',
#   'angrier',
#   'angrier',
#   'more',
#   'living',
#   'top',
#   'top.',
#   'plastic',
#   'Indian',
#   'one',
#   'wire.',
#   'color',
#   'time.',
#   'one',
#   'toy',
#   'toy',
#   'shit.',
#   'time.',
#   'bottom.',
#   'other',
#   'goddamn',
#   'age',
#   'question,',
#   'other.',
#   'other',
#   'difference',
#   'living',
#   'stairs.',
#   'living',
#   'girl,',
#   'baby,',
#   'little',
#   'way',
#   'house,',
#   'same.',
#   'middle',
#   'night.',
#   'morning,',
#   'bathroom,',
#   'most',
#   'bed.',
#   'blanket',
#   'edge',
#   'bed,',
#   'bed.',
#   'bathroom',
#   'middle',
#   'night,',
#   'bathroom.',
#   'squeaks',
#   'floor,',
#   'whole',
#   'bathroom',
#   'handle',
#   'knob',
#   'spring',
#   'fuck',
#   'only',
#   'inside',
#   'handle,',
#   'door',
#   'toilet.',
#   'toilet,',
#   'inside',
#   'bowl.',
#   'tiptoeing',
#   'side',
#   'bowl.',
#   'inside',
#   'bowl',
#   'pee',
#   'water,',
#   'seat',
#   'lid',
#   'noise',
#   'tank',
#   'bedroom.',
#   'bathroom,',
#   'mattress,',
#   'bed.',
#   'bed',
#   'bed,',
#   'bathroom.',
#   'bathroom',
#   'middle',
#   'night,',
#   'blankets.',
#   'blankets',
#   'bathroom,',
#   'door',
#   'door,',
#   'toilet.',
#   'world.',
#   'loudest',
#   'bedroom.',
#   'bedroom.',
#   'bedroom.',
#   'bed',
#   'bed',
#   'northern',
#   'Chinese',
#   'Filipinos,',
#   'Philippines.',
#   'Philippines',
#   'Philippines,',
#   'bumbais',
#   'nighttime.',
#   'streets.”',
#   'cakers?',
#   'Canadian',
#   'Canadian',
#   'exact',
#   'new',
#   'exact',
#   'puck',
#   'guys',
#   'real',
#   'U.S.,',
#   'mike',
#   'best',
#   'time.',
#   'thing',
#   'black',
#   'police',
#   'cops',
#   'suspect',
#   'age',
#   'political',
#   'white',
#   'body',
#   'bucket?”',
#   'world',
#   'whole',
#   'world',
#   'U.S.',
#   'entire',
#   'States',
#   'country',
#   'same.',
#   'time.',
#   'fuck',
#   'most',
#   'whole',
#   'Philippines.',
#   'whole',
#   'U.S.,',
#   'only',
#   'entire',
#   'five',
#   'hell',
#   'news.',
#   'news',
#   'best',
#   'craziest',
#   'American',
#   'media',
#   'American',
#   'people,',
#   'media.',
#   'news',
#   'worst',
#   'goat'],
#  'hell': ['did', 'am', 'is', 'happened?”', 'was'],
#  'did': ['you',
#   'it',
#   'you',
#   'you',
#   'you',
#   'to',
#   'you',
#   'they?',
#   'without.',
#   'you',
#   'good',
#   'we'],
#  'you': ['say',
#   'are.',
#   'are.',
#   'Filipino?',
#   'drive.',
#   'guys',
#   'were',
#   'realize',
#   'know',
#   'said?',
#   'think',
#   'practice?',
#   'must',
#   'been',
#   'to',
#   'study?',
#   'just',
#   'go',
#   'grow',
#   'can’t',
#   'fucking',
#   'think',
#   'as',
#   'were',
#   'had',
#   'know,',
#   'don’t',
#   'know?',
#   'had',
#   'were',
#   'what',
#   'feel',
#   'were',
#   'play',
#   'play',
#   'play?',
#   'wanted',
#   'were',
#   'need',
#   'need',
#   'want',
#   'become',
#   'were',
#   'become',
#   'can',
#   'put',
#   'do?”',
#   'do?”',
#   'going?”',
#   'do?”',
#   'work',
#   'do?”',
#   'for',
#   'need',
#   'realize',
#   'get',
#   'put?!”',
#   'want.',
#   'won’t',
#   'know',
#   'are',
#   'something,',
#   'take',
#   'put',
#   'put',
#   'can',
#   'do',
#   'good',
#   'can',
#   'work',
#   'prefer,',
#   'know',
#   'is…',
#   'know?',
#   'say',
#   'asking',
#   'use',
#   'made,',
#   'doing,',
#   'said',
#   'talk',
#   'been?”',
#   'guys',
#   'two.',
#   'have',
#   'were',
#   'doing?”',
#   'wanted,',
#   'need.',
#   'know?',
#   'loved',
#   'had',
#   'idle',
#   'to',
#   'what',
#   'not',
#   'a',
#   'can’t',
#   'weren’t',
#   'to',
#   'look',
#   'can’t',
#   'know?',
#   'can',
#   'pass',
#   'don’t',
#   'have,',
#   'look',
#   'grow',
#   'want',
#   'get',
#   'do',
#   'what',
#   'a',
#   'to',
#   'going?”',
#   'have?',
#   'like',
#   'like',
#   'which',
#   'love',
#   'love',
#   'like',
#   'hear',
#   'hear:',
#   'running',
#   'go.',
#   'said',
#   'okay,',
#   'a',
#   'need',
#   'move',
#   'grew',
#   'learning..?',
#   'speak',
#   'know',
#   'find',
#   'feel?”',
#   'from,',
#   'can',
#   'call',
#   'mean',
#   'know?',
#   'roll',
#   'woke',
#   'something',
#   'start',
#   'have',
#   'know?',
#   'go',
#   'have',
#   'have',
#   'get',
#   'could',
#   'get',
#   'have',
#   'gotta..',
#   'get',
#   'don’t',
#   'going',
#   'pee',
#   'know,',
#   'haven’t',
#   'sit',
#   'just',
#   'have',
#   'ever',
#   'doing,',
#   'been?',
#   'know',
#   'don’t',
#   'go.',
#   'grow',
#   'don’t',
#   'leave.',
#   'really',
#   'back',
#   'probably',
#   'really',
#   'know,',
#   'know,',
#   'know,',
#   'a',
#   'a',
#   'not…?',
#   'got',
#   'anyway?',
#   'have',
#   'can',
#   'know?',
#   'can',
#   'stop',
#   'gonna',
#   'picture',
#   'picture.',
#   'need',
#   'know?',
#   'look',
#   'travel',
#   'gone',
#   'gotta',
#   'so',
#   'something.',
#   'are.',
#   'were',
#   'gotta',
#   'know?',
#   'go?”',
#   'live',
#   'travel?”',
#   'go',
#   'came',
#   'guys',
#   'know.',
#   'this.',
#   'why',
#   'gotta',
#   'were',
#   'go',
#   'go,',
#   'go',
#   'in',
#   'don’t',
#   'get',
#   'better',
#   'don’t',
#   'very'],
#  'say': ['to',
#   '“and',
#   'so?',
#   '“how',
#   '“how',
#   'this.',
#   'and',
#   '“immigrant,”',
#   'you'],
#  'to': ['me?',
#   'do.',
#   'do',
#   'say.',
#   'him.',
#   'his',
#   'become',
#   'India?',
#   'India',
#   'become',
#   'become',
#   'you',
#   'an',
#   'become',
#   'an',
#   'an',
#   'be',
#   'become',
#   'be',
#   'be',
#   'be',
#   'be',
#   'be',
#   'whatever',
#   'be.',
#   'college.',
#   'you.',
#   'have',
#   'be',
#   'be',
#   'run',
#   'worry',
#   'work,',
#   'work,',
#   'work,',
#   'see',
#   'the',
#   'you',
#   'get',
#   'worry',
#   'the',
#   'worry',
#   'me',
#   'happen.',
#   'need',
#   'get',
#   'get',
#   'be',
#   'be',
#   'me.',
#   'be',
#   'get',
#   'a',
#   'tell',
#   'call',
#   'India.',
#   'do.',
#   'mirror',
#   'gain',
#   'your',
#   'your',
#   'pop-up',
#   'sound',
#   'Italian',
#   'them.',
#   'go',
#   'go',
#   'get',
#   'be,',
#   'do',
#   'your',
#   'try',
#   'my',
#   'replenish',
#   'bend',
#   'not',
#   'the',
#   'the',
#   'disappoint',
#   'get',
#   'Google.',
#   'look',
#   'a',
#   'have',
#   'cart.”',
#   'buy',
#   'the',
#   'happen',
#   'either',
#   'Canada?',
#   'take',
#   'take',
#   'say',
#   'say',
#   'me.',
#   'people',
#   'do',
#   'work,',
#   'the',
#   'tell',
#   'know',
#   'not',
#   'not',
#   'not',
#   'not',
#   'pee,',
#   'sleep.',
#   'tell',
#   'get',
#   'the',
#   'the',
#   'the',
#   'make',
#   'be',
#   'disturb',
#   'say,',
#   'react',
#   'it.',
#   'move.',
#   'say,',
#   'go',
#   'the',
#   'the',
#   'grip',
#   'open',
#   'push',
#   'go',
#   'the',
#   'the',
#   'pee…',
#   'the',
#   'the',
#   'the',
#   'mute',
#   'the',
#   'bed.',
#   'the',
#   'bed,',
#   'the',
#   'the',
#   'go',
#   'the',
#   'pee.”',
#   'make',
#   'the',
#   'lift',
#   'pee.',
#   'pee,',
#   'sit',
#   'flush,',
#   'wash',
#   'the',
#   'the',
#   'bed.',
#   'bed,',
#   'get',
#   'go',
#   'sleep.',
#   'bed,',
#   'me.”',
#   'a',
#   'play',
#   'ask',
#   'ask,',
#   'get',
#   'start',
#   'start',
#   'clean',
#   'travel',
#   'know',
#   'know',
#   'start',
#   'forget,',
#   'travel',
#   'India',
#   'India,',
#   'where',
#   'India,',
#   'India.',
#   'take',
#   'Egypt',
#   'sort',
#   'China,',
#   'Hong',
#   'Macao,',
#   'the',
#   'South',
#   'Italy..',
#   'him.',
#   'India,',
#   'India.',
#   'India.',
#   'India.',
#   'Brampton',
#   'India,',
#   'India.',
#   'Bombay.',
#   'worry.',
#   'just',
#   'panic.',
#   'my'],
#  'me?': ['Do', 'What', 'Remember'],
#  'Do': ['I', 'you', 'we', 'you', 'you', 'you', 'you', 'you'],
#  'I': ['look',
#   'believe',
#   'don’t',
#   'do',
#   'can’t',
#   'see',
#   'do.',
#   'see..',
#   'was',
#   'asked',
#   'go,',
#   'mean,',
#   'think',
#   'was',
#   'was',
#   'gotta',
#   'would',
#   'would',
#   'have',
#   'would',
#   'wanna',
#   'need',
#   'didn’t',
#   'thought',
#   'was',
#   'thought..',
#   'wanted',
#   'was..',
#   'was',
#   'was',
#   'always..',
#   'always',
#   'just',
#   'know',
#   'could',
#   'don’t',
#   'want',
#   'know',
#   'got',
#   'walk',
#   'want.',
#   'don’t',
#   'wanna',
#   'got',
#   'never',
#   'didn’t.',
#   'didn’t',
#   'didn’t',
#   'was',
#   'was',
#   'hated',
#   'never',
#   'mean?',
#   'never',
#   'never',
#   'was',
#   'stopped',
#   'go:',
#   'go,',
#   'can’t',
#   'know',
#   'chicken',
#   'know',
#   'told',
#   'was',
#   'was',
#   'go,',
#   'still',
#   'literally',
#   'don’t',
#   'mean,',
#   'did,',
#   'was',
#   'glorifying',
#   'got',
#   'was',
#   'die,',
#   'was',
#   'was',
#   'was',
#   'was.',
#   'was',
#   'was',
#   'gonna',
#   'was',
#   'do?”',
#   'said,',
#   'wanna',
#   'can’t.',
#   'use',
#   'am',
#   'use',
#   'go',
#   'download.”',
#   'have',
#   'have',
#   'don’t',
#   'am.',
#   'was',
#   'see',
#   'could',
#   'love',
#   'mean,',
#   'just',
#   'got',
#   'got',
#   'like',
#   'don’t',
#   'mean?',
#   'think',
#   'never',
#   'know',
#   'know',
#   'am.',
#   'don’t',
#   'know',
#   'am.',
#   'mean?',
#   'burst',
#   'want.',
#   'burst',
#   'guess',
#   'was',
#   'want',
#   'just',
#   'started',
#   'don’t',
#   'thought',
#   'laughed,',
#   'laughed.',
#   'thought',
#   'can’t',
#   'can’t',
#   'could',
#   'don’t',
#   'tell',
#   'never',
#   'needed.',
#   'never',
#   'mean,',
#   'never',
#   'would',
#   'have',
#   'would',
#   'got',
#   'start',
#   'wanted,',
#   'spoil',
#   'buy',
#   'buy',
#   'would',
#   'moved',
#   'was',
#   'had',
#   'do',
#   'didn’t',
#   'wanted',
#   'was',
#   'wanna',
#   'go,',
#   'pull',
#   'go',
#   'put',
#   'don’t',
#   'type',
#   'didn’t',
#   'want',
#   'mean,',
#   'go,',
#   'had',
#   'got',
#   'bought',
#   'never',
#   'was',
#   'moved',
#   'know..',
#   'was..',
#   'was',
#   'moved',
#   'don’t',
#   'just..',
#   'saw',
#   'figured',
#   'ask',
#   'don’t',
#   'thought',
#   'like',
#   'waited',
#   'just',
#   'swear.',
#   'go,',
#   'don’t',
#   'like',
#   'had',
#   'hired',
#   'called',
#   'go,',
#   'love',
#   'genuinely..',
#   'can',
#   'might',
#   'just',
#   'do',
#   'do.',
#   'didn’t',
#   'was',
#   'got',
#   'was',
#   'was',
#   'wanna',
#   'could',
#   'don’t',
#   'love',
#   'mean',
#   'mean,',
#   'will',
#   'would',
#   'will',
#   'was',
#   'know',
#   'have',
#   'don’t',
#   'go',
#   'start',
#   'try',
#   'finally',
#   'become',
#   'start',
#   'get',
#   'literally',
#   'get',
#   'know',
#   'avoid',
#   'tiptoe',
#   'open',
#   'turn',
#   'reach',
#   'grab',
#   'close',
#   'take',
#   'close',
#   'flush,',
#   'stand',
#   'wait',
#   'head',
#   'don’t',
#   'took',
#   'went',
#   'tiptoe',
#   'get',
#   'put',
#   'put',
#   'got',
#   'just',
#   'just..',
#   'kind',
#   'roll',
#   'left',
#   'gotta',
#   'don’t',
#   'go,',
#   'wake',
#   'was',
#   'didn’t',
#   'see',
#   'don’t',
#   'mean?',
#   'miss',
#   'love',
#   'come',
#   'never',
#   'left.',
#   'come',
#   'fucking',
#   'know',
#   'don’t',
#   'don’t',
#   'need',
#   'ain’t',
#   'know.',
#   'made',
#   'can',
#   'get',
#   'apologize.',
#   'would',
#   'don’t',
#   'don’t',
#   'don’t',
#   'think',
#   'don’t',
#   'ask:',
#   'travel',
#   'go',
#   'remember',
#   'was',
#   'haven’t',
#   'was',
#   'realized',
#   'can',
#   'would',
#   'love',
#   'love',
#   'love',
#   'mean,',
#   'first',
#   'knew',
#   'can’t'],
#  'look': ['like',
#   'at',
#   'young,',
#   'at',
#   'at',
#   'at',
#   'like',
#   'for',
#   'like',
#   'just',
#   'like',
#   'bored.',
#   'like:',
#   'at',
#   'what'],
#  'like': ['Ryan’s',
#   'watching,',
#   'eight',
#   'this',
#   'the',
#   'a',
#   'having',
#   'raw-dogging',
#   'I’m',
#   'her.',
#   'a',
#   'a',
#   'a',
#   'a',
#   'this',
#   'that,',
#   'a',
#   '“add',
#   'a',
#   'better?',
#   'better,',
#   'one',
#   'that.',
#   'listening',
#   'they’re',
#   'they',
#   'little',
#   'I’m',
#   'Superman.',
#   'a',
#   'a',
#   'a',
#   '40?”',
#   'a',
#   'regular',
#   'you.',
#   'regular'],
#  'Ryan’s': ['mom?'],
#  'mom?': ['Somebody'],
#  'Somebody': ['gonna'],
#  'gonna': ['get',
#   'turn',
#   'do',
#   'do',
#   'be',
#   'be',
#   'be',
#   'be',
#   'hurt',
#   'graduate?”',
#   'do',
#   'surf',
#   'get',
#   'be',
#   'be',
#   'do',
#   'be',
#   'go…',
#   'be',
#   'risk',
#   'go',
#   'tape',
#   'look.”',
#   'stop',
#   'get',
#   'die!”'],
#  'get': ['a',
#   'your',
#   '50.',
#   '50.”',
#   '25',
#   'a',
#   'a',
#   'on',
#   'anything.”',
#   'this',
#   'a',
#   'mad.',
#   'the',
#   'one',
#   'a',
#   'a',
#   'you',
#   '14',
#   'it',
#   'into',
#   'a',
#   'waken',
#   'up',
#   'to',
#   'up.',
#   'to',
#   'it',
#   'to',
#   'to',
#   'their',
#   'such',
#   'really',
#   'another',
#   'to',
#   'there',
#   'freaked'],
#  'a': ['hurt',
#   'big',
#   'lucky',
#   'living.',
#   'real',
#   'real',
#   'shot',
#   'butterfly',
#   'doctor.”',
#   'psychiatrist.”',
#   'doctor,',
#   'doctor',
#   'fucking',
#   'psychiatrist',
#   'doctor?”',
#   'doctor.',
#   'psychiatrist.”',
#   'heart',
#   'heart',
#   'doctor',
#   'doctor?',
#   'doctor',
#   'half',
#   'doctor,',
#   'half',
#   'doctor.',
#   'doctor.',
#   'half',
#   'billion',
#   'doctor.',
#   'doctor.',
#   'doctor,',
#   'doctor.',
#   'doctor.',
#   'doctor.',
#   'doctor,',
#   'doctor.',
#   'doctor.',
#   'doctor.”',
#   'doctor.”',
#   'doctor.',
#   '14-year-old',
#   'comedian.',
#   'dancer.',
#   'stripper.',
#   'break',
#   'realistic',
#   'good',
#   'musician.',
#   'musician.”',
#   'nickname.',
#   'doctor?”',
#   'doctor,',
#   'stethoscope,',
#   'black',
#   'doctor.”',
#   'doctor',
#   'lot',
#   'very',
#   'terrible',
#   'bunch',
#   'chicken',
#   'five-year-old',
#   'chicken',
#   'chicken',
#   'plant',
#   'minute.',
#   'cock.”',
#   'pass.',
#   'new',
#   'teenager.',
#   'career',
#   'job.',
#   'job,',
#   'profession.',
#   'job.”',
#   'job.',
#   'freeloader.',
#   'pilot.”',
#   'pilot?”',
#   'baggage',
#   'break-dancer.”',
#   'computer.',
#   'computer,',
#   'computer.',
#   'computer',
#   'living?',
#   'PC',
#   'Mac?',
#   'PC.',
#   'computer.',
#   'computer.',
#   'computer.”',
#   'computer',
#   'black',
#   'computer',
#   'Mac,',
#   'stupid',
#   'Mac',
#   'lot',
#   'Mac.',
#   'Mac',
#   'condom',
#   'PC',
#   'hooker,',
#   'problem',
#   'problem',
#   'forest',
#   'daily',
#   'pop-up.”',
#   'day.”',
#   'few',
#   'daughter,',
#   'new',
#   'schiaffo',
#   '5-year-old.',
#   'woman.',
#   'little',
#   'woman',
#   'motherfucker,',
#   'motherfucker,',
#   'motherfucker.',
#   'comedian.',
#   'shit',
#   'real',
#   'TV.',
#   'TV,',
#   'speaker',
#   'shelving',
#   'turntable',
#   'cassette',
#   'shitty',
#   'vase',
#   'wire,',
#   'vase',
#   'flower',
#   'wire',
#   'coupon.',
#   'pair.”',
#   'year.',
#   'bullshit',
#   'little',
#   'little',
#   'really',
#   'really',
#   'really',
#   'fun',
#   'castle',
#   'castle',
#   'queen-sized',
#   'double',
#   'steeple',
#   'castle.',
#   'slide',
#   '$10,000',
#   '3-year-old.',
#   'queen-sized',
#   'queen-sized',
#   'loser.”',
#   'son.',
#   'sudden,',
#   'sudden,',
#   'second,',
#   'hostage?',
#   'shit',
#   'blackjack',
#   'real',
#   'swear',
#   'sleeper.',
#   'day,',
#   'koala',
#   'job',
#   'man..',
#   'nightmare.',
#   'bladder',
#   'minute',
#   'safety',
#   'shower',
#   'minute',
#   'guy',
#   'woman’s',
#   'woman',
#   'shit',
#   'cat,',
#   'hippopotamus,',
#   'woman',
#   'flush.',
#   'glass,',
#   'light',
#   'beam',
#   'normal',
#   'pep',
#   'threat',
#   'shitty',
#   'fucking',
#   'hockey',
#   'team',
#   'good',
#   'weird',
#   'time',
#   'big',
#   'black',
#   'black',
#   'dark-ass',
#   'black',
#   'black',
#   'black',
#   'black',
#   'black',
#   'black',
#   'black',
#   'hard',
#   'black',
#   'black',
#   'living',
#   'regular',
#   'few',
#   'wonderful',
#   'great',
#   'kid.',
#   'suitcase.”',
#   'sheep',
#   'train',
#   'lot',
#   'daily',
#   'couple',
#   'sad',
#   'problem',
#   'bicycle',
#   'goat.',
#   'delicious'],
#  'hurt': ['real', 'and'],
#  'real': ['bad.',
#   'doctor?',
#   'doctor,',
#   'doctors',
#   'reason',
#   'reason,',
#   'woman.',
#   'swear',
#   'proper',
#   'Canadian.'],
#  'bad.': ['Oh,', 'Like,'],
#  'Oh,': ['DDR.',
#   'my',
#   'yeah,',
#   'my',
#   'wow,',
#   'okay.',
#   'general',
#   'yeah.',
#   'my',
#   'shit.',
#   'shit.',
#   'that’s',
#   'you’re',
#   'my',
#   'my',
#   'Mylanta.',
#   'my',
#   'my',
#   'yeah.',
#   'he’s',
#   'shit,',
#   'yeah,',
#   'my',
#   'yeah.',
#   'yeah.”'],
#  'DDR.': ['So'],
#  'So': ['good.'],
#  'good.': ['His', 'I..', 'That’s', '-You', 'Kids?', 'I', 'It’s', 'But'],
#  'His': ['best'],
#  'best': ['buddy', 'of', 'thing'],
#  'buddy': ['is', 'with'],
#  'in': ['the',
#   'Chinese',
#   'any',
#   'HR',
#   'my',
#   'no',
#   'shit.',
#   'Hamilton,',
#   'four',
#   'India.',
#   'India.',
#   'this',
#   'the',
#   'your',
#   'and',
#   'America',
#   'the',
#   'the',
#   'Mississauga.',
#   'my',
#   'Kmart.',
#   'head',
#   'the',
#   'it.',
#   'grade',
#   'school',
#   'school,',
#   'my',
#   'India',
#   'the',
#   'the',
#   'value,',
#   'my',
#   'her',
#   'and',
#   'here,',
#   'the',
#   'my',
#   'the',
#   'it',
#   'the',
#   'September',
#   'this',
#   'that.',
#   'two',
#   '“cool',
#   'it',
#   'the',
#   'the',
#   'the',
#   'Poland.',
#   'Poland,',
#   'Russian.',
#   'Russian,',
#   'Russian,',
#   'Los',
#   'my',
#   '1989,',
#   'the',
#   'the',
#   'your',
#   'the',
#   'the',
#   'case',
#   'the',
#   'four',
#   'the',
#   'there?',
#   'there.',
#   'the',
#   'the',
#   'the',
#   'the',
#   'town?”',
#   'an',
#   'Canada.',
#   'a',
#   'a',
#   'the',
#   'it,',
#   'their',
#   'about',
#   'the',
#   'Canada.',
#   'the',
#   'the',
#   'the',
#   'North',
#   'this',
#   'North',
#   'the',
#   'Bombay.',
#   'less',
#   'advance.',
#   'my',
#   'your',
#   'India',
#   'your',
#   'your',
#   'India',
#   'America',
#   'America,',
#   'India.',
#   'your'],
#  'house.': ['Best', 'I’m', 'I', 'I'],
#  'Best': ['what?', 'buddy.'],
#  'what?': ['Best', 'Look'],
#  'buddy.': ['Oh,', 'So,', 'Let'],
#  'my': ['God.',
#   'city.',
#   'God.',
#   'audience',
#   'God.',
#   'people',
#   'doctor,',
#   'dream',
#   'life.',
#   'doctor',
#   'doctor',
#   'doctor',
#   'life.',
#   'parents',
#   'parents..',
#   'family',
#   'dad',
#   'job.”',
#   'dad',
#   'dad',
#   'dad',
#   'dad',
#   'parents',
#   'typing..',
#   'dad',
#   'dad',
#   'God.',
#   'God.',
#   'God,',
#   'God.',
#   'God.',
#   'God!',
#   'God!',
#   'life',
#   'laptop',
#   'laptop.”',
#   'password?”',
#   'good',
#   'name',
#   'forest',
#   'computer?',
#   'screen.',
#   'history.',
#   'God!',
#   'daughter',
#   'life,',
#   'house,',
#   'daughter',
#   'little',
#   'life,',
#   'parents.',
#   'dad',
#   'daughter.',
#   'birthday.',
#   'dad',
#   'dad',
#   'daughter.',
#   'daughter.',
#   'laptop,',
#   'daughter’s',
#   'parents’',
#   'God.',
#   'God!”',
#   'God!',
#   'house',
#   'last',
#   'Russian',
#   'last',
#   'last',
#   'friends,',
#   'friend',
#   'girlfriend’s',
#   'God!',
#   'God.',
#   'girlfriend’s',
#   'sleep,',
#   'side',
#   'announcement.',
#   'hands.',
#   'dick.',
#   'balls.',
#   'way',
#   'shoulder',
#   'whole',
#   'arm',
#   'God!',
#   'entire',
#   'God.',
#   'job',
#   'family',
#   'favorite',
#   'room.”',
#   'God!',
#   'favorite',
#   'diabetes…'],
#  'God.': ['Thank',
#   'I’m',
#   'That',
#   'My',
#   'Son,',
#   'Oh,',
#   'Son,',
#   'Who',
#   'Thank',
#   'Did'],
#  'Thank': ['you.', 'God', 'you'],
#  'you.': ['All',
#   'Thanks.',
#   'I',
#   'All',
#   'I',
#   'Just',
#   'Let',
#   'I',
#   'I',
#   'Just',
#   'Are',
#   'They'],
#  'All': ['right!',
#   'right.',
#   'right.',
#   'right.',
#   'right.',
#   'right?',
#   'right.',
#   'right?',
#   'you',
#   'right?',
#   'those',
#   'of',
#   'right.',
#   'over.”'],
#  'right!': ['And'],
#  'And': ['now,',
#   'where’s',
#   'that’s',
#   'where',
#   'Dr.',
#   'how',
#   'they',
#   'she’s',
#   'it',
#   'you',
#   'everybody',
#   'then',
#   'then',
#   'I',
#   'I',
#   'if',
#   'your',
#   'your',
#   'I’m',
#   'you',
#   'I',
#   'so,',
#   'I',
#   'then',
#   'she',
#   'if',
#   'I',
#   'I',
#   'the',
#   'the',
#   'I’m',
#   'then',
#   'nobody',
#   'we’d',
#   'I',
#   'I',
#   'she’s',
#   'then',
#   'we’ll',
#   'all',
#   'then..',
#   'she',
#   'I’m',
#   'then,',
#   'it',
#   'then',
#   'I',
#   'we’re',
#   'she’s',
#   'I’m',
#   'my',
#   'I',
#   'I',
#   'this',
#   'that',
#   'she’s',
#   'my',
#   'when',
#   'I',
#   'I',
#   'I',
#   'more',
#   'then',
#   'then',
#   'when',
#   'while',
#   'she’s',
#   'I',
#   'you’re',
#   'then',
#   'then…',
#   'then',
#   'then',
#   'then',
#   'just',
#   'then',
#   'then',
#   'she',
#   'we',
#   'then',
#   'this',
#   'you',
#   'then',
#   'now',
#   'she',
#   'she',
#   'this',
#   'she’s',
#   'she..',
#   'she',
#   'then',
#   'your',
#   'it’s',
#   'I',
#   'if',
#   'then',
#   'that’s',
#   'old',
#   'you',
#   'whether',
#   'going',
#   'you',
#   'an'],
#  'now,': ['ladies', 'you', 'especially', 'right?'],
#  'ladies': ['and', 'and'],
#  'and': ['gentlemen,',
#   'the',
#   'Starting',
#   'gentlemen.',
#   'learning',
#   'this',
#   'a',
#   'a',
#   'you’re',
#   'a',
#   'he’s',
#   'raised',
#   'raised',
#   'it',
#   'I',
#   'went,',
#   'picked',
#   'it',
#   'shit.”',
#   'shit.',
#   'shit.”',
#   'I',
#   'then',
#   'I',
#   'get',
#   'goes:',
#   'I',
#   'you',
#   'you',
#   'avoid',
#   'I',
#   'then:',
#   'you',
#   'done',
#   'I',
#   'done.',
#   'I..',
#   'I’m',
#   'just',
#   'my',
#   'an',
#   'you',
#   'they',
#   'half',
#   'it',
#   'my',
#   'you',
#   'I',
#   'then',
#   'she',
#   'a',
#   'son.',
#   'walking.',
#   'all',
#   'some',
#   'I',
#   'then',
#   'giggle.”',
#   'I',
#   'then',
#   'my',
#   'then',
#   'sleepy',
#   'do',
#   'you’re',
#   'I',
#   'then',
#   'then:',
#   'the…and',
#   'there’s',
#   'the',
#   'I',
#   'I',
#   'only',
#   'then',
#   'then',
#   'then:',
#   'went',
#   'think,',
#   'go,',
#   'I’m',
#   'finds',
#   'pee?',
#   'go:?',
#   'she',
#   'then..',
#   'Edward,',
#   'raised',
#   'you',
#   'dumb',
#   'sound',
#   'look',
#   'see',
#   'Indian',
#   'Indian',
#   'spell',
#   'the',
#   '97.',
#   'no',
#   'see',
#   'raised',
#   'see',
#   'I',
#   'back',
#   'you',
#   'seeing',
#   'Bombay',
#   'smell',
#   'drive',
#   'get',
#   'watch',
#   'propaganda.',
#   'he’s'],
#  'gentlemen,': ['Canada’s'],
#  'Canada’s': ['own'],
#  'own': ['and'],
#  'pride': ['of'],
#  'of': ['Brampton,',
#   'Asian.',
#   'Asian',
#   'doctor',
#   'doctor',
#   'surgeon?',
#   'the',
#   'that.',
#   'doctor',
#   'a',
#   'your',
#   'all,',
#   'the',
#   'determination',
#   'my',
#   'all,',
#   'all,',
#   'Mississauga,',
#   'sentences.',
#   'Indian',
#   'dummies.',
#   'the',
#   'them.',
#   'it',
#   'millions',
#   'people’s',
#   'questionable',
#   'it.',
#   'those',
#   'everything',
#   'all,',
#   'shoes',
#   'sneakers.”',
#   'money.',
#   '3.',
#   'my',
#   'them',
#   'them,',
#   'your',
#   'a',
#   'a',
#   'my',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'all,',
#   'all,',
#   'ten,',
#   'weight',
#   'roll.',
#   'roll',
#   'the',
#   'her',
#   'her',
#   'me',
#   'bed',
#   'her',
#   'her',
#   'light',
#   'getting',
#   'Asian',
#   'hockey.”',
#   'race',
#   'both',
#   'the',
#   'reference',
#   '18',
#   'it.',
#   'his',
#   'three.',
#   'things.',
#   'ours,',
#   'my',
#   'New',
#   'people',
#   'people.',
#   'those'],
#  'Brampton,': ['Ontario…'],
#  'Ontario…': ['Toronto,'],
#  'Toronto,': ['give'],
#  'give': ['it', 'it', 'you', 'a', 'a', 'me'],
#  'it': ['up',
#   'up',
#   'take',
#   'into',
#   'was',
#   'wasn’t',
#   'was',
#   'to',
#   'on',
#   'on',
#   'on',
#   'down,',
#   'really',
#   'is.”',
#   'startled',
#   'when',
#   'when',
#   'was',
#   'was',
#   'was',
#   'was',
#   'was',
#   'was',
#   'for',
#   'takes',
#   'was',
#   'as',
#   '’cause',
#   'has',
#   'has',
#   'gonna',
#   'be',
#   'once!',
#   'didn’t',
#   'means',
#   'wrong.',
#   'out.”',
#   'takes',
#   'takes',
#   'takes',
#   'takes',
#   'feel',
#   'so',
#   'unlocked,',
#   'swiftly.',
#   'open',
#   'slow,',
#   'goes:',
#   'was',
#   'first.',
#   'that',
#   'slips',
#   'doesn’t',
#   'just',
#   'until',
#   'sounds',
#   'in',
#   'hits',
#   'was'],
#  'up': ['for',
#   'for,',
#   'fairly',
#   'all',
#   'on',
#   'a',
#   'with',
#   'in',
#   'early.',
#   'when',
#   'just',
#   'in',
#   'wanting',
#   'like',
#   'my',
#   'when',
#   'online.',
#   'in',
#   'in',
#   'to',
#   'for',
#   '’cause',
#   'and',
#   'the',
#   'and',
#   'right',
#   'out',
#   'and',
#   'and'],
#  'for': ['your',
#   'sure.',
#   'a',
#   'sure.',
#   'an',
#   'the',
#   'a',
#   'me.',
#   'a',
#   'signing',
#   'that',
#   'a',
#   'a',
#   'me.',
#   'no',
#   'school,',
#   'my',
#   'little',
#   'you.”',
#   'a',
#   'fuck',
#   'a',
#   'me.',
#   '27',
#   'sleep.',
#   'the',
#   'ten',
#   'openings',
#   'me.',
#   'ten',
#   'you',
#   'America.',
#   'Americans.',
#   'the'],
#  'your': ['hometown',
#   'name?',
#   'name?',
#   'Chinese',
#   'Chinese',
#   'buddy',
#   'chest.',
#   'name,',
#   'family',
#   'name?',
#   'dream',
#   'dream',
#   'dream',
#   'room,',
#   'name,',
#   'face?”',
#   'guitar',
#   'nasal',
#   'shit',
#   'name',
#   'break.”',
#   'good',
#   'first',
#   'computer.”',
#   'computer.”',
#   'laptop',
#   'laptop.',
#   'history.”',
#   'name?',
#   'lovely',
#   'parents.',
#   'head.',
#   'kid',
#   'dad',
#   'parents',
#   'child',
#   'kids?',
#   'name?',
#   'children',
#   'son',
#   'name,',
#   'family',
#   'girlfriend,',
#   'wife?',
#   'name?',
#   'pipes',
#   'man',
#   'sleep,',
#   'sleep.',
#   'body',
#   'body’s',
#   'life.',
#   'shoulder',
#   'name',
#   'blood',
#   'parents',
#   'immigrants,',
#   'name?',
#   'mom',
#   'shit',
#   'hotel',
#   'life.',
#   'life.',
#   'life'],
#  'hometown': ['boy,'],
#  'boy,': ['Russell…'],
#  'Russell…': ['Peters.'],
#  'Peters.': ['Hey,', 'Seems', 'Mr.'],
#  'Hey,': ['thank', 'give', 'giant', 'motherfucker,', 'man,'],
#  'thank': ['you.'],
#  'Thanks.': ['All'],
#  'right.': ['There', 'Hey,', 'I…', 'Uh..', 'First', 'You’re', 'Where', 'That'],
#  'There': ['you', 'you', 'are', 'were', 'you', 'we'],
#  'are.': ['There', 'There’s', 'I'],
#  'There’s': ['my', 'a', 'no', 'no', 'a'],
#  'city.': ['Heh.'],
#  'Heh.': ['That’s', 'I..', 'Lusty'],
#  'That’s': ['it.',
#   'what',
#   'the',
#   'the',
#   'a..',
#   'like',
#   'why',
#   'a',
#   'not',
#   'a',
#   'all',
#   'why',
#   'how',
#   'the',
#   'the',
#   'never',
#   '‘putting.’',
#   'how',
#   'the',
#   'great.',
#   'good.',
#   'nice.',
#   'all',
#   'a',
#   'your',
#   'good.',
#   'the',
#   'some',
#   'a',
#   'how',
#   'right.',
#   'all',
#   'going',
#   'not',
#   'going',
#   'how',
#   'how',
#   'how',
#   'how'],
#  'it.': ['That’s',
#   'But..',
#   'That',
#   'I',
#   'But',
#   'I',
#   'Genius.',
#   'I',
#   'Not',
#   'I',
#   'She',
#   'And',
#   'And',
#   'Like,',
#   'This',
#   'But…',
#   'Um…',
#   'You',
#   'You'],
#  'what': ['I’m',
#   'are',
#   'you',
#   'makes',
#   'a',
#   'my',
#   'I',
#   'happened.',
#   'I',
#   'he',
#   'my',
#   'a',
#   'I',
#   'a',
#   'exactly',
#   'that',
#   'he',
#   'does',
#   'I’m',
#   'she',
#   'we’re',
#   'I',
#   'an',
#   'an',
#   'I',
#   'I’m',
#   'happened.',
#   'I’m',
#   'BiWay',
#   'happened.',
#   'they',
#   'I’m',
#   'I',
#   'you',
#   'they’re'],
#  'I’m': ['talking',
#   'so',
#   'not',
#   'mad',
#   'concerned.',
#   'glad',
#   'trying',
#   'like,',
#   'a',
#   'gonna',
#   'right.',
#   'gonna',
#   'five',
#   'not',
#   'like,',
#   'going',
#   'alive.',
#   'here,',
#   'going',
#   'not',
#   'impressed',
#   'shit',
#   'not',
#   'trying',
#   'not',
#   'scared.',
#   'so',
#   'all',
#   'like,',
#   'going',
#   'doing',
#   'going',
#   'pregnant.”',
#   'not..',
#   'not',
#   'one',
#   'talking',
#   'like,',
#   'doing?!”',
#   'a',
#   'just',
#   'like,',
#   'gonna',
#   'like,',
#   'not',
#   'trying',
#   'like,',
#   'like',
#   'like,',
#   'like,',
#   'not',
#   'like,',
#   'like,',
#   'what',
#   'lazy',
#   'trying',
#   'good.',
#   'gonna',
#   'like,',
#   'sleeping',
#   'like,',
#   'like,',
#   'gonna',
#   'gonna',
#   'doing',
#   'pushing',
#   'still',
#   'able',
#   'done,',
#   'trying',
#   'like,',
#   'doing',
#   'asking',
#   'gonna',
#   'gonna',
#   'like,',
#   'really',
#   'fucking',
#   'in',
#   'like,',
#   'waiting',
#   'in',
#   'good.',
#   'like,'],
#  'talking': ['about.', 'to', 'about.', 'backwards.', 'to'],
#  'about.': ['Hey,', 'A', 'Immigrant'],
#  'for,': ['uh,', 'I'],
#  'uh,': ['DJ', 'Saudi.', 'you'],
#  'DJ': ['Spinbad'],
#  'Spinbad': ['and'],
#  'Starting': ['From'],
#  'From': ['Scratch,', 'a', 'Italy?'],
#  'Scratch,': ['ladies'],
#  'gentlemen.': ['Live'],
#  'Live': ['DJing.'],
#  'DJing.': ['Live.'],
#  'Live.': ['Not', 'Asian'],
#  'Not': ['dead.',
#   'a',
#   'in',
#   'you',
#   'like',
#   'wanting',
#   'building..',
#   'had.',
#   'been'],
#  'dead.': ['Live.'],
#  'Asian': ['guy,', 'guy.', 'are', 'are', 'guy.', 'guy’s'],
#  'guy,': ['how', 'that’s', 'but'],
#  'how': ['are',
#   'to',
#   'long',
#   'I',
#   'dumb',
#   'you',
#   'to',
#   'angry',
#   'to',
#   'to',
#   'do',
#   'you',
#   'are',
#   'old',
#   'they',
#   'the',
#   'they',
#   'they'],
#  'are': ['you?',
#   'you?',
#   'you?',
#   'supposed',
#   'you?',
#   'you?',
#   'you?',
#   'you?”',
#   'you?',
#   'like,',
#   'ridiculous.',
#   'no',
#   'you',
#   'good',
#   'far',
#   'at',
#   'an',
#   'stupid-people',
#   'you',
#   'you?',
#   'you',
#   'you,',
#   'you',
#   'you',
#   'they?',
#   'you?”',
#   'you?”',
#   'you?',
#   'you',
#   'from',
#   'from',
#   'they',
#   'they',
#   'blocked.”',
#   'in',
#   'you,',
#   'you,',
#   'such',
#   'the',
#   'you?',
#   'you?”',
#   'you',
#   'you,',
#   'you',
#   'you?',
#   'you,',
#   'dead…'],
#  'you?': ['Good.',
#   '-Chinese.',
#   '-Six',
#   '-Gynecologist.',
#   '-Orthopedic.',
#   '-Surgeon.',
#   '-Forty-one.',
#   '-How',
#   '-You',
#   'Sir?',
#   'How'],
#  'Good.': ['You’re', 'I'],
#  'You’re': ['looking',
#   'Chinese.',
#   'about',
#   'sitting',
#   'Chinese.',
#   'making',
#   'supposed',
#   'like,',
#   'just,',
#   'Italian.',
#   '36.',
#   'in',
#   'in',
#   'still',
#   'born',
#   'a',
#   'a',
#   'obviously'],
#  'looking': ['very', 'at,', 'at'],
#  'very': ['anime.',
#   'well',
#   'young',
#   'important.',
#   'firmly.',
#   'important.',
#   'much,'],
#  'anime.': ['-What'],
#  '-What': ['style..?', 'style', 'kind', 'kind', 'kind', 'do', 'do', 'is'],
#  'style..?': ['Are'],
#  'Are': ['you',
#   'you..?',
#   'there',
#   'you',
#   'those',
#   'they..?',
#   'you',
#   'you..?',
#   'you',
#   'there',
#   'you',
#   'you',
#   'you'],
#  'Filipino?': ['-Chinese.'],
#  '-Chinese.': ['Chinese.', 'You’re'],
#  'Chinese.': ['That’s', 'Look', 'You’d'],
#  'main': ['kind'],
#  'kind': ['of', 'of', 'of', 'of', 'of', 'of', 'of', 'of'],
#  'Asian.': ['That’s..', 'Brown,', 'That’s'],
#  'That’s..': ['That’s', 'How', 'There', 'That’s'],
#  'one': ['they',
#   'night,',
#   'that',
#   'day,',
#   'home.',
#   'kid.',
#   'and',
#   'of',
#   'and',
#   'single',
#   'flower,',
#   'time,',
#   'pair',
#   'new',
#   'toy',
#   'do',
#   'do',
#   'you',
#   'better.',
#   'of',
#   'are',
#   'of',
#   'that',
#   'leg',
#   'of',
#   'minute.',
#   'of'],
#  'they': ['make',
#   'don’t',
#   'never',
#   'popped',
#   'don’t',
#   'tell',
#   'fucking',
#   'wouldn’t',
#   'were',
#   'were',
#   'were.',
#   'were',
#   'might',
#   'speaking',
#   'didn’t',
#   'would',
#   'would',
#   'laughing',
#   'call',
#   'saying?”',
#   'call',
#   'come',
#   'have',
#   'didn’t',
#   'just',
#   'look',
#   'look',
#   'open',
#   'always',
#   'were',
#   'control',
#   'think.',
#   'control',
#   'have',
#   'cut'],
#  'make': ['the', 'you', 'no', 'an', 'extra', 'me'],
#  'most': ['of.', 'stealth-like', 'hush-hush'],
#  'of.': ['They,'],
#  'They,': ['uh…'],
#  'uh…': ['You', '-What’s', 'Dr.', 'I’m', 'not'],
#  'You': ['can',
#   'doing',
#   'good?',
#   'can’t',
#   'insulted',
#   'could',
#   'know',
#   'can',
#   'know,',
#   'fill',
#   'know',
#   'ask',
#   'can’t',
#   'know',
#   'know,',
#   'want',
#   'good?',
#   'don’t',
#   'need',
#   'waited.',
#   'know?',
#   'know',
#   'know',
#   'know',
#   'don’t',
#   'know?',
#   'are,',
#   'gotta',
#   'know,',
#   'know,',
#   'guys',
#   'don’t',
#   'grew',
#   'ever',
#   'know,',
#   'just',
#   'have',
#   'have',
#   'can’t',
#   'have',
#   'just',
#   'gotta..',
#   'gotta..',
#   'pee',
#   'don’t',
#   'gotta',
#   'woke',
#   'know',
#   'were',
#   'should',
#   'realize',
#   'might',
#   'can',
#   'know',
#   'always',
#   'will',
#   'hear',
#   'know?',
#   'got',
#   'know,',
#   'hear',
#   'didn’t',
#   'need',
#   'can',
#   'gotta',
#   'know?',
#   'must',
#   'gotta',
#   'go',
#   'gotta',
#   'gotta',
#   'watch',
#   'were'],
#  'can': ['pick',
#   'do,',
#   'relax.”',
#   'just',
#   'fix',
#   'dance',
#   'do,',
#   'do',
#   'be',
#   'you',
#   'have',
#   'backfire',
#   'clear',
#   'get',
#   'hear',
#   'run',
#   'never',
#   'tell',
#   'always',
#   'go',
#   'only',
#   'no'],
#  'pick': ['them'],
#  'them': ['up', 'all', 'or', 'I’m', 'more', 'both', 'with'],
#  'fairly': ['cheap.'],
#  'cheap.': ['They’re'],
#  'They’re': ['reasonably', 'not'],
#  'reasonably': ['priced.', 'priced.'],
#  'priced.': ['They’re..', 'They'],
#  'They’re..': ['-Heh,'],
#  '-Heh,': ['what’s'],
#  'what’s': ['your', 'your'],
#  'name?': ['-Kat',
#   '-Edward.',
#   '-Sandeep.',
#   'What',
#   'What',
#   '-Vince.',
#   '-Greg.',
#   '-Anand.',
#   'Hello.'],
#  '-Kat': ['Sang'],
#  'Sang': ['Bong.'],
#  'Bong.': ['I’ll..'],
#  'I’ll..': ['I’ll'],
#  'I’ll': ['do',
#   'tell',
#   'burst',
#   'throw',
#   'do',
#   'do',
#   'be',
#   'do',
#   'get',
#   'tell',
#   'warn'],
#  'do': ['the',
#   'you',
#   'this',
#   'something',
#   'you',
#   'you',
#   'for',
#   'this',
#   'you',
#   'you',
#   'you',
#   'you',
#   'at',
#   'I',
#   'something',
#   'is',
#   'you',
#   'you..?”',
#   'you',
#   'something,',
#   'that.',
#   'it',
#   'it',
#   'whatever',
#   'something,',
#   'that',
#   'it.',
#   'have.',
#   'you',
#   'you',
#   'you',
#   'you',
#   'some',
#   'you',
#   'love',
#   'whatever',
#   'the',
#   'whatever',
#   'that',
#   'whatever',
#   'whatever',
#   'it,',
#   'it',
#   'I',
#   'this',
#   'it',
#   'you',
#   'you',
#   'it.',
#   'you'],
#  'jokes': ['now.', 'you'],
#  'now.': ['Are', 'It’s', 'It’s'],
#  'you..?': ['You', 'Are', 'You’re'],
#  'doing': ['comedy',
#   'smart,',
#   'at',
#   'an',
#   'anything',
#   'some',
#   'anything',
#   'stand-up',
#   'that,',
#   'it.',
#   'this',
#   'over'],
#  'comedy': ['is'],
#  'watching,': ['well,'],
#  'well,': ['you', 'well.', 'well.'],
#  'drive.': ['Uh,'],
#  'Uh,': ['that’s..', 'last'],
#  'that’s..': ['That’s..'],
#  'How': ['you',
#   'many',
#   'old',
#   'long',
#   'gangster',
#   'do',
#   'about',
#   'you',
#   'are',
#   'old?',
#   'old',
#   'you',
#   'did',
#   'are',
#   'old',
#   'many'],
#  'guys': ['doing?', 'yell', 'been', 'go,', 'come', 'out', 'to'],
#  'doing?': ['You'],
#  'good?': ['All', '-Pretty', 'What’s'],
#  'giant': ['Asian', 'black'],
#  'guy.': ['That’s', 'I', '-Black', 'The', 'But'],
#  'a..': ['Crickey,', 'Any', 'Springtime', 'A'],
#  'Crickey,': ['you’re'],
#  'you’re': ['a',
#   'here?',
#   'cutting',
#   'the',
#   'not',
#   'on',
#   'having',
#   'brand',
#   'a',
#   'doing',
#   'going',
#   'not',
#   'going',
#   'good',
#   'gonna',
#   'angry.',
#   'getting',
#   'watching',
#   'a',
#   'speaking',
#   'not',
#   'sleeping',
#   'like,',
#   'the',
#   'looking',
#   'gonna',
#   'Indian',
#   'like,'],
#  'big': ['one.', 'deal'],
#  'one.': ['Um..', 'I', 'It’s'],
#  'Um..': ['-What'],
#  'style': ['of', 'of'],
#  'Look': ['at', 'at', 'pissed', 'at', 'at', 'at', 'at', 'at'],
#  'at': ['that.',
#   'things',
#   'that.',
#   'that',
#   '14',
#   '14.',
#   'the',
#   'me',
#   'a',
#   'a',
#   'stake.”',
#   'the',
#   'this',
#   'this',
#   'the',
#   '5,',
#   'you!”',
#   'you.',
#   'it',
#   'the',
#   'beds',
#   'stuff.',
#   'her,',
#   'the',
#   'you,',
#   'some',
#   'Greg.',
#   'them,',
#   'their',
#   'all?',
#   'all?',
#   'things.'],
#  'that.': ['-How',
#   'I,',
#   'Only',
#   'Oh,',
#   'I,',
#   'I,',
#   'If',
#   'That’s',
#   'There’s',
#   'This',
#   'I',
#   'When',
#   'Start'],
#  '-How': ['tall', 'long', 'many?', 'old', 'old'],
#  'tall': ['are'],
#  '-Six': ['feet.'],
#  'feet.': ['Six', 'Which'],
#  'Six': ['feet'],
#  'feet': ['in..'],
#  'in..': ['In', 'Especially'],
#  'In': ['Chinese,', 'North', 'Russian,', 'the'],
#  'Chinese,': ['that’s'],
#  'that’s': ['like…',
#   'interesting.',
#   'a..',
#   'your',
#   'a..',
#   'my',
#   'the..',
#   'the..',
#   'because',
#   'when',
#   'pretty',
#   'the',
#   'the',
#   'sphinx.',
#   'all',
#   'fine',
#   'an',
#   'not'],
#  'like…': ['That’s'],
#  'eight': ['feet.'],
#  'Which': ['in', 'one', 'is'],
#  'Chinese': ['is', 'name,', 'name.', 'guys.', 'names.'],
#  'lucky': ['number.'],
#  'number.': ['So,'],
#  'So,': ['that’s…',
#   'out',
#   'you',
#   'you',
#   'you..',
#   'one',
#   'I',
#   'this',
#   'I..',
#   'try',
#   'we',
#   'now,',
#   'when',
#   'I',
#   'we',
#   'I’m',
#   'that’s',
#   'when',
#   'yeah,',
#   'I',
#   'that',
#   'you',
#   'you',
#   'then',
#   'I',
#   'now',
#   'you’re',
#   'you'],
#  'that’s…': ['-What’s'],
#  '-What’s': ['your', 'your', 'your', 'your'],
#  '-Edward.': ['Edward.'],
#  'Edward.': ['Oh,'],
#  'yeah,': ['for', 'that', 'you’re', 'yeah.'],
#  'sure.': ['Yeah.', 'Got'],
#  'Yeah.': ['No',
#   'Ooh.',
#   'First',
#   'Yeah.',
#   'So,',
#   'So,',
#   '-What',
#   'That’s',
#   'From',
#   'You',
#   'I',
#   'There’s..',
#   'Look.',
#   'There',
#   'That’s..'],
#  'No': ['doubt.', 'way!', 'problem.', 'doubt.', 'doubt,', 'doubt.”', 'doubt.'],
#  'doubt.': ['Absolutely', 'No', 'Oh!”', 'No', 'Oh,'],
#  'Absolutely': ['I'],
#  'believe': ['that.', 'I’m', 'me?'],
#  'I,': ['uh…', 'uh..', 'uh..', 'too,', 'uh..', 'uh…'],
#  'name,': ['Edward?', 'Dr.', 'Edwoo.', 'buddy?'],
#  'Edward?': ['-I…', 'You’re'],
#  '-I…': ['I…'],
#  'I…': ['I', 'Well,', 'Oh,', 'And'],
#  'don’t': ['know',
#   'learn',
#   'have',
#   'you',
#   'want',
#   'want',
#   'know',
#   'die.”',
#   'need',
#   'die',
#   'die.”',
#   'believe',
#   'care',
#   'care',
#   'have',
#   'need',
#   'want',
#   'want',
#   'play.',
#   'give',
#   'talk',
#   'know',
#   'shush',
#   'have',
#   'know',
#   'you',
#   'need',
#   'wanna',
#   'think',
#   'want',
#   'give',
#   'you',
#   'know,',
#   'know',
#   'wanna',
#   'wanna',
#   'wanna',
#   'wash',
#   'even',
#   'wake',
#   'know',
#   'go',
#   'see',
#   'notice',
#   'hear',
#   'know.',
#   'think',
#   'know..',
#   'know',
#   'know',
#   'mean',
#   'have',
#   'believe'],
#  'know': ['if',
#   'why',
#   'why?',
#   'this',
#   'what',
#   'I',
#   'what',
#   'what',
#   'what',
#   'what',
#   'what',
#   'anybody',
#   'you’re',
#   'that’s',
#   'how',
#   'what',
#   'me,',
#   'what',
#   'what',
#   'what',
#   'what',
#   'if',
#   'why',
#   'she',
#   'how',
#   'how.”',
#   'that',
#   'this..',
#   'what?',
#   'where',
#   'where',
#   'that',
#   'this?',
#   'that',
#   'you',
#   'that?',
#   'better.',
#   'better.',
#   'how',
#   'what'],
#  'if': ['you',
#   'that',
#   'not',
#   'I’m',
#   'the',
#   'you',
#   'you’re',
#   'your',
#   'that’s',
#   'I’m',
#   'you',
#   'you’re',
#   'she',
#   'you',
#   'you',
#   'you',
#   'they',
#   'any'],
#  'were': ['hesitating',
#   'born',
#   '14',
#   '14,',
#   'thinking,',
#   'like,',
#   'like,',
#   'like,',
#   'no',
#   'on',
#   'huge',
#   'like',
#   'on',
#   'never',
#   'all',
#   'mad.',
#   'so',
#   'you',
#   'great',
#   'reasonably',
#   'on',
#   'tidy.',
#   'respectful.',
#   'born',
#   'like,',
#   'taught,',
#   'like,',
#   'born',
#   'awesome.'],
#  'hesitating': ['or'],
#  'or': ['if',
#   'there?',
#   'not.”',
#   'a',
#   'a',
#   'cleaned',
#   'son?',
#   'understand',
#   'something,',
#   'white',
#   'the'],
#  'that': ['was',
#   'involve',
#   'many',
#   'a',
#   'what',
#   'eyebrow.',
#   'became',
#   'was',
#   'became',
#   'became',
#   'means',
#   'kind',
#   'are',
#   'they',
#   'could',
#   'says,',
#   'pressure.',
#   'Indian',
#   'a',
#   'you',
#   'my',
#   'meant.',
#   'job.',
#   'bothers',
#   'that',
#   'guy',
#   'mean?”',
#   'way.”',
#   'your',
#   'I',
#   'TV',
#   'ran',
#   'were',
#   'was',
#   'plus',
#   'lead',
#   'comes',
#   'one!”',
#   'one,',
#   'was',
#   'your',
#   'makes',
#   'your',
#   'until',
#   'I’m',
#   'way',
#   'you',
#   'can',
#   'I',
#   'way,',
#   'they',
#   'bathroom',
#   'it',
#   'my',
#   'Indian',
#   'I',
#   'way?',
#   'coming.',
#   'your',
#   'you',
#   'happens'],
#  'was': ['your',
#   'like,',
#   'already',
#   'actually',
#   'born',
#   'never',
#   'gonna',
#   'a',
#   'like,',
#   'your',
#   'all',
#   'like,',
#   'an',
#   'a',
#   'five,',
#   'going',
#   '12,',
#   'like,',
#   'going',
#   'in',
#   '1984.',
#   'actual',
#   '13',
#   'like,',
#   'a',
#   'it.',
#   'their',
#   '16,',
#   'like,',
#   'like,',
#   'hiring',
#   'like,',
#   'like,',
#   'like,',
#   'in',
#   'a',
#   'in',
#   'like,',
#   'just..',
#   'hilarious.',
#   'the',
#   'just',
#   '1975',
#   'more',
#   'a',
#   'a',
#   'a',
#   'so',
#   'only',
#   'like,',
#   'such',
#   'building..',
#   'like,',
#   'three',
#   'like..',
#   'sitting',
#   '30.',
#   'because',
#   '30',
#   '36.',
#   'that?”',
#   'that?”',
#   'younger?',
#   'like:',
#   'standing',
#   'like,',
#   'having',
#   'asleep',
#   'just',
#   'in',
#   'a',
#   'going',
#   'the',
#   'talking',
#   'that?'],
#  'name.': ['I…', 'Your', 'Enchanted?', 'In'],
#  'Well,': ['that’s',
#   'you',
#   'good.',
#   'that',
#   'don’t',
#   'a',
#   'what',
#   'you',
#   'the'],
#  'interesting.': ['I…'],
#  'glad': ['this', 'there’s'],
#  'this': ['job',
#   'in',
#   'shit',
#   'Indian',
#   'gentleman’s',
#   'shit',
#   'part',
#   'job',
#   'shit',
#   'little',
#   'shit.',
#   'is',
#   'way.',
#   'pot.”',
#   'one.”',
#   'new',
#   'is',
#   'pot',
#   'long,',
#   'big,',
#   'bucket',
#   'new',
#   'castle',
#   'little',
#   'up',
#   'because',
#   'because',
#   'game.”',
#   'is',
#   'is',
#   'little',
#   'beautiful,',
#   'asshole',
#   'weight’s',
#   'year.',
#   'room.',
#   '27',
#   'whole',
#   'continent,',
#   'weekend…'],
#  'job': ['worked', 'existed.', 'entail?”', 'is,', 'where', 'is'],
#  'worked': ['out,', 'in'],
#  'out,': ['guys,', 'you’re'],
#  'guys,': ['’cause..', 'you', 'this', 'this'],
#  '’cause..': ['You'],
#  'can’t': ['act',
#   'do.',
#   'let',
#   'tell',
#   'comprehend',
#   'get',
#   'do',
#   'picture..',
#   'even',
#   'do',
#   'you',
#   'catch',
#   'pronounce'],
#  'act': ['like'],
#  'any': ['other',
#   'doctors',
#   'instruments?',
#   'words,',
#   'kids',
#   'Russian',
#   'problems.',
#   'one'],
#  'other': ['job.',
#   'doctor?',
#   'doctor?',
#   'dreams',
#   'for',
#   'side.',
#   'is',
#   'than',
#   'place'],
#  'job.': ['Do', 'Well,', 'I’m', 'People’s'],
#  'realize': ['that?', 'you', 'that?'],
#  'that?': ['I’d',
#   'My',
#   'Slow',
#   'Let’s…”',
#   '“Bro,',
#   'We',
#   'I',
#   'You',
#   '“Ebola’s'],
#  'I’d': ['be', 'go', 'leave', 'never..'],
#  'be': ['in',
#   'honest',
#   'honest.',
#   'a',
#   'a',
#   'a',
#   'logical.',
#   'the',
#   'a',
#   'a',
#   'honest.',
#   'in',
#   'a',
#   'a',
#   'your',
#   'an',
#   'a',
#   'the',
#   'a',
#   'a',
#   'some',
#   'such',
#   'like,',
#   'in',
#   'a',
#   'a',
#   'stupid.',
#   'a',
#   'good',
#   'good',
#   'good',
#   '‘Lost.’',
#   'the',
#   'doing',
#   'here.',
#   'at',
#   'like,',
#   'like,',
#   'here',
#   'here?”',
#   'yours.',
#   'looking..',
#   'something.”',
#   'loud.',
#   'like,',
#   'like,',
#   'a',
#   'wrong',
#   'Bombay,',
#   'standing',
#   'honest.',
#   'right',
#   'a',
#   'held'],
#  'HR': ['every'],
#  'every': ['day.', 'disadvantage.', 'year', 'day'],
#  'day.': ['-Russell,', 'The'],
#  '-Russell,': ['do'],
#  'why': ['you’re', 'I', 'I', 'they', 'can’t', 'you'],
#  'here?': ['-No.', 'All'],
#  '-No.': ['You', 'No?', '-No,'],
#  'insulted': ['somebody.'],
#  'somebody.': ['Who?'],
#  'Who?': ['Everybody.'],
#  'Everybody.': ['I’m'],
#  'not': ['good',
#   'a',
#   'hoping',
#   'more.',
#   'like..',
#   'even',
#   'you,',
#   'what',
#   'a',
#   'bragging,',
#   'a',
#   'in',
#   'a',
#   'good',
#   'good',
#   'gonna',
#   'go',
#   'fucking',
#   'going',
#   'gonna',
#   'see',
#   'disappoint',
#   'an',
#   'asking',
#   'Egyptian,',
#   'because..',
#   'disturb',
#   'ruin',
#   'disturb',
#   'disturb',
#   'playing',
#   'there,',
#   'a',
#   'reach',
#   'white',
#   'fucking',
#   'traveling.',
#   'traveling.',
#   'dangerous,',
#   'leave'],
#  'good': ['at',
#   'start.',
#   'or',
#   'on',
#   'on',
#   'on',
#   'on',
#   'on',
#   'on',
#   'on',
#   'name?”',
#   'name.”',
#   'name?',
#   'name.',
#   'name?”',
#   'name?”',
#   'work.',
#   'game',
#   'thing'],
#  'things': ['Indian', 'that', 'about', 'that'],
#  'Indian': ['people',
#   'people',
#   'people',
#   'guy',
#   'guy',
#   'woman',
#   'woman',
#   'woman',
#   'guys',
#   'kid',
#   'pressure',
#   'kids',
#   'people',
#   'guy',
#   'world.',
#   'community.',
#   'guy,',
#   'people',
#   'people',
#   'guy.',
#   'guy.',
#   'guy?',
#   'people',
#   'and',
#   'people'],
#  'people': ['are',
#   'can',
#   'doing',
#   'right',
#   'were',
#   'that',
#   'are',
#   'can',
#   'who',
#   'speak',
#   'speak',
#   'here?',
#   'in',
#   'as',
#   'talk',
#   'say',
#   'with',
#   'need',
#   'try',
#   'to..',
#   'in',
#   'there.',
#   'have',
#   'are'],
#  'supposed': ['to', 'to'],
#  'do.': ['That’s', 'I’m', 'Anytime', 'I’m', 'Look', 'And', 'Don’t', 'That’s'],
#  'shit': ['for',
#   'goes',
#   'on',
#   'you’re',
#   'forever.”',
#   'that',
#   'together.',
#   'out',
#   'on',
#   'parent.',
#   'she',
#   'I’d',
#   'if',
#   'if',
#   'going',
#   'quiet.”',
#   'like:',
#   'out.',
#   'ton'],
#  'living.': ['Anything'],
#  'Anything': ['Indian', 'Indian'],
#  'do,': ['I', 'I'],
#  'mad': ['envious', 'at'],
#  'envious': ['when'],
#  'when': ['I',
#   'you',
#   'you',
#   'I',
#   'I',
#   'I’d',
#   'I',
#   'I',
#   'you',
#   'you’re',
#   'everything’s',
#   'TVs',
#   'it',
#   'you',
#   'you',
#   'I’m',
#   'I',
#   'I',
#   'you',
#   'they',
#   'we’re',
#   'I’m',
#   'you',
#   'I',
#   'I',
#   'you',
#   'you',
#   'I’m',
#   'a',
#   'I',
#   'a',
#   'you',
#   'she’s',
#   'she’s',
#   'I',
#   'you',
#   'I',
#   'I’m',
#   'it',
#   'people',
#   'I'],
#  'see': ['Indian',
#   'if',
#   'the',
#   'that?',
#   'what',
#   'what',
#   'white',
#   'real',
#   'the',
#   'that',
#   'all',
#   'it.'],
#  'smart,': ['intelligent'],
#  'intelligent': ['things'],
#  'involve': ['studying'],
#  'studying': ['and'],
#  'learning': ['how'],
#  'something': ['good.', 'else.', 'great.”', 'intelligent.', 'else.', 'a'],
#  'I..': ['I', 'I', 'I', 'And', 'My'],
#  'Anytime': ['I'],
#  'see..': ['Like'],
#  'Like': ['doctors.',
#   'Edward,',
#   'in',
#   'computers.',
#   'coil',
#   'in..',
#   'nothing'],
#  'doctors.': ['How', 'Where’s', 'Hurry'],
#  'many': ['doctors?', 'fucking', 'times', 'people'],
#  'doctors?': ['Are'],
#  'there': ['any', 'any', 'and', 'tonight', 'and,', 'and', 'to'],
#  'doctors': ['here', 'here,', 'here?”,'],
#  'here': ['tonight?', 'tomorrow?”', 'offering'],
#  'tonight?': ['Look'],
#  'Only': ['in'],
#  'audience': ['we', 'one'],
#  'we': ['have',
#   'have',
#   'just',
#   'had',
#   'grew',
#   'find',
#   'work.',
#   'don’t',
#   'do',
#   'get',
#   'go.',
#   'need',
#   'live'],
#  'have': ['that',
#   'a',
#   'boy',
#   'to',
#   'Indian',
#   'had',
#   'that',
#   'that',
#   'a',
#   'to',
#   'a',
#   'gained',
#   'kids?',
#   'ever',
#   'to',
#   'a',
#   'anything',
#   'wanted',
#   'that',
#   'kids,',
#   'a',
#   'been',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'no',
#   'a',
#   'to',
#   'to',
#   'a',
#   'been',
#   'never',
#   'to',
#   'the',
#   'it?”',
#   'these'],
#  'fucking': ['doctors.',
#   'incredible.',
#   'psychiatrist.',
#   'dummies.',
#   'name',
#   'thing!”',
#   'collecting',
#   'mean',
#   'years,',
#   'Hulk',
#   'hear.',
#   'hologram',
#   'doubt.',
#   'doubt,',
#   'stare',
#   'with',
#   'traveling.'],
#  'Where’s': ['the', 'the', 'your'],
#  'doctor': ['over',
#   'are',
#   'are',
#   'are',
#   'is',
#   'than',
#   'for?',
#   'in',
#   'to',
#   'in',
#   'to',
#   'and',
#   'I',
#   'for',
#   'to'],
#  'over': ['there?', 'here.', 'after', 'in', 'in', 'a', 'there?', 'there.'],
#  'there?': ['-What', '-Hamilton.', 'And', 'I', 'You'],
#  '-Gynecologist.': ['Gynecologist.'],
#  'Gynecologist.': ['Oh,'],
#  'wow,': ['that’s'],
#  'Any': ['openings?'],
#  'openings?': ['Oh,'],
#  'okay.': ['All'],
#  'where’s': ['the'],
#  'doctor?': ['You,', 'Let', '-And', '-A'],
#  'You,': ['bro?'],
#  'bro?': ['-What', '-Yeah,'],
#  '-Orthopedic.': ['Orthopedic.'],
#  'Orthopedic.': ['Is'],
#  'Is': ['that', 'that', 'it', 'that', 'your..?', 'that'],
#  'Let': ['me', 'me', 'me', 'me', 'me', 'me', 'me', 'me'],
#  'me': ['ask',
#   'go',
#   'if',
#   'tomorrow,',
#   'and',
#   'know.”',
#   'to',
#   'to',
#   'tell',
#   'happy.',
#   'is',
#   'now?”',
#   'tell',
#   'tell',
#   'first',
#   'just',
#   'explain.',
#   'all',
#   'just',
#   'any',
#   'by',
#   'Russell?”',
#   'by',
#   'up.',
#   'and',
#   'wanna',
#   'tell',
#   'two',
#   'tell',
#   'of'],
#  'ask': ['the', 'my', 'which', 'a'],
#  'gynecologist.': ['Uh.'],
#  'Uh.': ['No.'],
#  'No.': ['She', 'I', 'She', 'We'],
#  'She': ['says',
#   'bent',
#   'reacted',
#   'got',
#   'became',
#   'was',
#   'goes,',
#   'has',
#   'doesn’t',
#   'doesn’t',
#   'goes',
#   'turns'],
#  'says': ['no.', 'we'],
#  'no.': ['Where’s', 'Oh,', 'Oh,', 'Oh,'],
#  '-And': ['what', 'is'],
#  '-Surgeon.': ['Surgeon.'],
#  'Surgeon.': ['That’s'],
#  'doctor,': ['as',
#   'ever.”',
#   'four',
#   'especially',
#   'that',
#   'you',
#   'you',
#   '’cause'],
#  'as': ['far',
#   'I’m',
#   'much,',
#   'a',
#   'many',
#   'you',
#   'well.',
#   'two',
#   'much',
#   'possible.',
#   'a',
#   'a',
#   'old',
#   'I’m',
#   'I’m',
#   'a'],
#  'far': ['as', 'too'],
#  'concerned.': ['-What'],
#  'surgeon?': ['-General', 'Is'],
#  '-General': ['surgeon.'],
#  'surgeon.': ['Gen..', 'Oh,'],
#  'Gen..': ['Genital'],
#  'Genital': ['surgeon?'],
#  'said?': ['Or'],
#  'Or': ['general?', 'if'],
#  'general?': ['Oh,'],
#  'general': ['surgeon.'],
#  'yeah.': ['That', 'How', 'You', 'Kevin', 'Are', 'No', 'Right', 'No.'],
#  'That': ['makes..',
#   'is',
#   'is..',
#   'is',
#   'thing’s',
#   'your',
#   'didn’t',
#   'was',
#   'was',
#   'makes',
#   'joke',
#   'make'],
#  'makes..': ['I'],
#  'like,': ['“Hey,',
#   '“I’m',
#   '“That’s',
#   '“There’s',
#   '“They',
#   '“Fuck',
#   '“We',
#   '“Oh,',
#   '“Yeah,',
#   '“Sweetie,',
#   '“Fuck',
#   '“Yo,',
#   '“What’s',
#   '“Yo,',
#   '“Ain’t',
#   '“Oh,',
#   '“Dad..”',
#   '“Son,',
#   '“Son…',
#   '“Dad,',
#   '“I’m',
#   '“Of',
#   '“Oh,',
#   '“You',
#   '“Damn.',
#   '“I',
#   '“Yes,',
#   'I',
#   'the',
#   '“I',
#   '“Baby!”',
#   '“Baby!”',
#   '“Daddy!',
#   '“I',
#   'half',
#   '“Son,',
#   '“Yes.”',
#   '“Let’s',
#   '“You',
#   '“Baby,',
#   '“I',
#   '“I',
#   '“I',
#   '“Will',
#   '“Fuck',
#   '“What?”',
#   '“For',
#   '“It’s',
#   '“What',
#   '“Yo,',
#   'an',
#   '“I’ll',
#   '“Oh,',
#   '3:30',
#   '“You',
#   '“Nah,',
#   '“Shut',
#   '“I’m',
#   '“If',
#   '“Yes!”',
#   '“There’s',
#   '“Donald',
#   '“Me?',
#   '“Russell!”',
#   '“That’s',
#   '“You',
#   '“I’m',
#   '“Oh,'],
#  '“Hey,': ['you’re', 'Vince.', 'kak', 'hey,', 'didn’t', 'is', 'hey,'],
#  'cutting': ['into', 'concrete'],
#  'into': ['her',
#   'a',
#   'four',
#   'the',
#   'her',
#   'whatever',
# ...
#  'parents': ['are',
#   'knew',
#   'were',
#   'never',
#   'gave',
#   'don’t',
#   'were',
#   'had',
#   'are',
#   'are',
#   'from'],
#  '“Sweetie,': ['you'],
#  'marry': ['a'],
#  'she’s': ['like,',
#   'five.',
#   'like,',
#   'like,',
#   'not',
#   'dreaming.',
#   'done,',
#   'done.',
#   'stomping',
#   'coming'],
#  'wanna': ['be',
#   'play',
#   'talk',
#   'be',
#   'get',
#   'look',
#   'get',
#   'disturb',
#   'make..',
#   'break',
#   'jitterbug.”'],
#  'determination': ['from'],
#  'from': ['my', 'the', 'the', 'Uzbekistan.', 'Uzbekistan.', 'Canada,', 'his'],
#  'know?': ['Well,',
#   'You’re',
#   'She',
#   'So,',
#   'As',
#   'Like,',
#   'But…',
#   'So,',
#   'That’s',
#   'And',
#   'But',
#   'Like,',
#   'By'],
#  'dreams': ['when', 'about.', 'that', 'about'],
#  '14': ['years', 'should', 'hours'],
#  'old,': ['right,'],
#  'right,': ['Sandeep?'],
#  'Sandeep?': ['And', 'Now,'],
#  'wasn’t': ['to', 'to', 'till', 'dragging'],
#  '14-year-old': ['dreams'],
#  '14-year-old…': ['has'],
#  'has': ['dreams', 'to', 'a', 'a', 'a', 'no', 'to', 'an'],
#  'ridiculous.': ['That..'],
#  'dream': ['at', 'was.', 'was.', 'when', 'about'],
#  'should': ['never', 'be', 'be'],
#  'logical.': ['It'],
#  'It': ['should',
#   'wasn’t',
#   'wasn’t',
#   'was',
#   'was',
#   'feels',
#   'burns',
#   'was',
#   'had',
#   'had',
#   'had',
#   'was..',
#   'was',
#   'was',
#   'doesn’t',
#   'doesn’t',
#   'wasn’t'],
#  'dumbest': ['shit'],
#  '14.': ['I’ll', 'My', 'Your'],
#  'tell': ['you',
#   'a',
#   'you',
#   'you',
#   'by',
#   'you',
#   'you',
#   'them',
#   'you',
#   'you.',
#   'you',
#   'a',
#   'by',
#   'you',
#   'anybody.”',
#   'you',
#   'you'],
#  'was.': ['It', 'Here’s', 'My'],
#  'comedian.': ['I', 'Or'],
#  'existed.': ['My'],
#  'My': ['dream..',
#   'doctor',
#   'parents',
#   'parents',
#   'mom',
#   'dad',
#   'final',
#   'only',
#   'dad',
#   'dad',
#   'dad',
#   'dad',
#   'password?',
#   'daughter',
#   'daughter’s',
#   'dad',
#   'birthday',
#   'daughter’s',
#   'brother',
#   'son',
#   'parents',
#   'name',
#   'dad'],
#  'dream..': ['It’ll'],
#  'It’ll': ['make'],
#  'feel': ['better', 'like'],
#  'better': ['about', 'be', 'go', 'not'],
#  'about': ['whatever',
#   '17,',
#   'being',
#   'doing',
#   'school.',
#   'a',
#   'that?',
#   'it.',
#   'how',
#   'seeing.',
#   'it.',
#   'ten',
#   'peeing.',
#   'peeing,',
#   'playing',
#   'it',
#   'the',
#   '45',
#   'my',
#   'my'],
#  'whatever': ['your', 'you', 'room', 'it', 'it', 'it', 'it', 'it'],
#  'Here’s': ['what', 'how', 'what'],
#  'thought': ['I', 'you', 'it', 'it', 'about', 'you', 'I'],
#  'rest': ['of', 'of'],
#  'life.': ['I', 'I', 'I', 'They', 'Like,'],
#  'thought..': ['Heh.'],
#  'dancer.': ['All'],
#  'fuck': ['you.', 'with', 'is', 'is', 'the', 'sakes.”', 'up,', 'you'],
#  'Second': ['of', 'of', 'of'],
#  'stripper.': ['I'],
#  'was..': ['I', 'I’m', 'It', 'I', 'He'],
#  'break': ['dancer,', 'water.'],
#  'dancer,': ['and'],
#  '“Yo,': ['I’m', 'coz,', 'these', 'I'],
#  'forever.”': ['Not'],
#  'realistic': ['goal,'],
#  'goal,': ['though.'],
#  'though.': ['What', 'My', 'Regular'],
#  '14,': ['growing'],
#  'growing': ['up'],
#  'mean': ['streets', 'do', 'gay?”', 'sleeping', 'go'],
#  'streets': ['of'],
#  'Now,': ['be', 'I', 'when', 'when'],
#  'Don’t': ['make', 'be', 'judge', 'come', 'get', 'tell'],
#  'bullshit': ['up.', 'deal,'],
#  'musician.': ['-Huh?', '-Did', 'I'],
#  '-Huh?': ['A'],
#  '-Did': ['you'],
#  'play': ['any', 'basketball?”', 'guitar.”', 'more'],
#  'instruments?': ['-Yes.'],
#  '-Yes.': ['Well,', '-How', '-You', '-Yes.', 'That’s'],
#  'start.': ['I'],
#  'always..': ['I'],
#  'always': ['have', 'say', 'have', 'tell', 'look', 'look'],
#  'yell': ['out'],
#  'did.': ['“I', '“What', 'I', 'My'],
#  '“I': ['wanted',
#   'work.”',
#   'work',
#   'check',
#   'wanna',
#   '‘putted’',
#   '‘putted’?”',
#   'ain’t',
#   'know',
#   'don’t',
#   'don’t',
#   'have',
#   'thought',
#   'do.',
#   'can’t!”',
#   'want',
#   'want',
#   'want',
#   'want',
#   'better',
#   'just',
#   'just',
#   'just',
#   'have'],
#  'NBA.”': ['“Did'],
#  '“Did': ['you'],
#  'basketball?”': ['“Not'],
#  '“Not': ['once.', 'the'],
#  'once.': ['I', 'They'],
#  'love': ['giant',
#   'talking',
#   'more.',
#   'either',
#   'them',
#   'sleep.',
#   'sleep.',
#   'what',
#   'sleep.',
#   'when',
#   'Bombay.',
#   'Bombay',
#   'New'],
#  'black': ['men.”',
#   'guy',
#   'guy',
#   'guy',
#   'guy',
#   'guy',
#   'guy?',
#   'guy?',
#   'guy',
#   'guy?',
#   'person',
#   'person’s',
#   'people.',
#   'person’s',
#   'community',
#   'man',
#   'male',
#   'and'],
#  'men.”': ['You'],
#  'just..': ['What', 'Shh!', 'I', 'You', 'I', 'I'],
#  'instrument': ['did'],
#  'play?': ['-Guitar.'],
#  '-Guitar.': ['-You'],
#  '-You': ['good?', 'still', 'spoil', 'have', 'love', 'had', 'Russian,'],
#  '-Pretty': ['good.', 'well.'],
#  'still': ['throw', 'didn’t', 'gonna', 'there.'],
#  'throw': ['down', 'that'],
#  'down': ['on', 'and', 'the', 'to', 'to', 'and', 'and', 'the'],
#  'it?': ['-Pretty', '-Yeah.', '“Oh,'],
#  'well.': ['Yeah.', 'All', 'Heh.', 'I'],
#  'happened.': ['Tell', 'My', 'Couple'],
#  'Tell': ['me'],
#  '17,': ['18'],
#  '18': ['years', 'and'],
#  'old.': ['You’re', 'I'],
#  'sitting': ['in', 'right'],
#  'room,': ['playing', 'right?', 'watching', 'you’re', 'watching'],
#  'playing': ['with', 'this', 'tennis.'],
#  'your…': ['“guitar.”'],
#  '“guitar.”': ['And…'],
#  'And…': ['you', 'I'],
#  'thinking,': ['“I’m'],
#  'musician.”': ['Your'],
#  'mom': ['walked', 'walked', 'worked', 'with'],
#  'walked': ['in', 'in:', 'up'],
#  'went,': ['“Sandoo…”', '“Motherfucker!'],
#  '“Sandoo…”': ['That’s'],
#  'nickname.': ['All'],
#  'add': ['two'],
#  'two': ['O’s',
#   'pieces.”',
#   'guns?',
#   'more',
#   'Russian',
#   'flushes.',
#   'days’',
#   'days,'],
#  'O’s': ['to'],
#  'want': ['the',
#   'my',
#   'my',
#   'my',
#   'me',
#   'my',
#   'more',
#   'my',
#   'you',
#   'things,',
#   'a',
#   'a',
#   'a',
#   'that',
#   'you',
#   'anything',
#   'us'],
#  'nickname': ['to'],
#  'be.': ['Sandoo.'],
#  'Sandoo.': ['Like..'],
#  'Like..': ['Like'],
#  'Edward,': ['Edwoo.', 'the'],
#  'Edwoo.': ['Well,', 'Sorry,'],
#  'Sorry,': ['that..', 'buddy.'],
#  'that..': ['That'],
#  'work,': ['’cause', 'my', 'I', 'I', 'they'],
#  '’cause': ['he',
#   'he’ll',
#   'I',
#   'I',
#   'I’m',
#   'I',
#   'your',
#   'she',
#   'you',
#   'the',
#   'they',
#   'look',
#   'I'],
#  'he': ['might',
#   'gonna',
#   'just',
#   'did.',
#   'left.',
#   'left.',
#   'did',
#   'bought',
#   'bought',
#   'could'],
#  'might': ['very', 'be', 'have', 'be'],
#  'well': ['be'],
#  'Ed': ['Woo.'],
#  'Woo.': ['Your'],
#  'in:': ['“Sandoo…'],
#  '“Sandoo…': ['you’re'],
#  'going': ['to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'north.”',
#   'up',
#   'through',
#   'on.',
#   'to',
#   'in',
#   'back',
#   'to',
#   'to',
#   'to',
#   'there'],
#  'college.': ['Why'],
#  '“What’s': ['wrong', 'that?”'],
#  'wrong': ['with', '100'],
#  'face?”': ['“If'],
#  '“If': ['you', 'you'],
#  'fix': ['it.”'],
#  'it.”': ['So,', '“Like…', 'So,', '“You'],
#  'put': ['your', 'it', 'it', 'it', 'it.”', 'safe', 'my', 'your', 'one'],
#  'guitar': ['down'],
#  'picked': ['up'],
#  'stethoscope,': ['and'],
#  'after': ['that.', '40,', 'these'],
#  'being': ['something', 'you’ve'],
#  'else.': ['My', 'You', 'It’s'],
#  'America': ['is', 'just', 'would', 'loves', '’cause'],
#  'who': ['grew', 'grew', 'I', 'needs', 'gets'],
#  'grew': ['up', 'up', 'up', 'up', 'up'],
#  'disadvantage.': ['Real'],
#  'Real': ['‘hood.', 'crazy.”'],
#  '‘hood.': ['Like', 'Where'],
#  '“‘hood”': ['‘hood.'],
#  'the..': ['Where', 'That’s', '“I', 'What'],
#  'coz,': ['let’s'],
#  'let’s': ['go'],
#  'kill': ['some'],
#  'some': ['motherfuckers',
#   'bratty',
#   'illegal',
#   'guy',
#   'plumbing',
#   'shit.',
#   'point.'],
#  'motherfuckers': ['today.”'],
#  'today.”': ['I'],
#  'says,': ['“No,'],
#  '“No,': ['man.', 'son.', 'sir.Your', 'sir.', 'no,', 'it’s', 'fucking'],
#  'man.': ['I’m', 'Russell.”'],
#  'everybody': ['in', 'on'],
#  '“Ain’t': ['nobody'],
#  'nobody': ['fuck', 'ever'],
#  'Daverel,': ['he'],
#  'shit.”': ['That’s', 'I', 'I'],
#  'he’ll': ['say'],
#  '“and': ['shit”'],
#  'shit”': ['at'],
#  'end': ['of'],
#  'sentences.': ['Look'],
#  'pissed': ['off'],
#  'off': ['when', 'me!”', 'of', 'of'],
#  'walk': ['into', 'out', 'by,'],
#  'office.': ['That’s'],
#  'want.': ['“Hi,', 'But…', 'So,'],
#  '“Hi,': ['Mr.'],
#  'Mr.': ['Peters.', 'Peter.”', 'Peters.”'],
#  'Seems': ['your', 'to'],
#  'nasal': ['passage'],
#  'passage': ['is'],
#  'inflamed': ['and'],
#  'fill': ['out'],
#  'little': ['bitch-ass',
#   'kid.',
#   'daughter',
#   'money,',
#   'bit',
#   'girls.”',
#   'bitch',
#   'girl,',
#   'bit.',
#   'kids.',
#   'jujitsu',
#   'woman'],
#  'bitch-ass': ['prescription.'],
#  'prescription.': ['Holler'],
#  'Holler': ['at'],
#  'tomorrow,': ['motherfucker.”'],
#  'motherfucker.”': ['That’s'],
#  'me.': ['I',
#   'They’ll',
#   'There',
#   '“A',
#   'I',
#   'And',
#   'He',
#   'Um…',
#   'I',
#   'As',
#   'Before'],
#  'bratty': ['Indian'],
#  'kid': ['who', 'comes', 'ever'],
#  'Mississauga.': ['When'],
#  'operation,': ['he'],
#  'goes,': ['“Fuck',
#   '“Work.”',
#   '“Well,',
#   '“Baggage',
#   '“Well,',
#   '“Okay.”',
#   '“Daddy,',
#   '“Where',
#   '“Hey,',
#   '“What',
#   '“Comedian.”',
#   '“Fuck'],
#  'guitar.”': ['Then'],
#  'Then': ['the', 'I', 'he’s', 'when', 'I', 'I', 'she', 'she', 'she', 'they'],
#  'run': ['in,', 'down', 'fast'],
#  'in,': ['“Don’t', '“Russell.”'],
#  '“Don’t': ['worry,', 'die.', 'be'],
#  'worry,': ['dog.'],
#  'dog.': ['I'],
#  'this.': ['It’s', 'But..', 'They', 'I'],
#  'worry': ['about', 'about', 'about'],
#  'anything': ['great', 'weird.', 'in', 'bad', 'bad'],
#  'great': ['with', 'guys.', 'place.'],
#  'didn’t.': ['I'],
#  'pressure.': ['I'],
#  'pressure': ['that'],
#  'lot': ['of', 'of', 'of'],
#  'kids': ['have.', 'is', 'in', 'to'],
#  'have.': ['“Do', 'Not', '-Yeah.'],
#  '“Do': ['something', 'you'],
#  'great.”': ['My'],
#  'knew': ['I', 'it’d'],
#  'idiot.': ['From', 'You'],
#  'young': ['age,'],
#  'age,': ['my'],
#  'man.”': ['I', 'I', 'I'],
#  'terrible': ['student.'],
#  'student.': ['I'],
#  'hated': ['school.'],
#  'school.': ['I', 'I'],
#  'parents..': ['My'],
#  'careers.': ['They'],
#  'professions.': ['They'],
#  'jobs.': ['There', 'My'],
#  'professionals': ['in'],
#  'either': ['side.', 'of', 'of'],
#  'side.': ['Just', 'My'],
#  'Just': ['a', 'regular', 'get', 'mad.', 'sleeping.'],
#  'bunch': ['of'],
#  'mean?': ['But', 'They’re', '“Yeah.', 'Where'],
#  'But': ['regular',
#   'my',
#   'what',
#   'you',
#   'she',
#   'my',
#   'I',
#   'I',
#   'other',
#   'you’re',
#   'you',
#   'their',
#   'white',
#   'if',
#   'he’s'],
#  'regular': ['hard-working', 'jobs.', 'white', 'white', 'white'],
#  'hard-working': ['people.'],
#  'people.': ['Just',
#   'The',
#   'I',
#   'You',
#   'They',
#   'You',
#   'Look',
#   'What’s',
#   'It’s',
#   'They',
#   'That’s'],
#  'Kmart.': ['Not..'],
#  'Not..': ['Not'],
#  'head': ['office,', 'back'],
#  'office,': ['in'],
#  'store.': ['My'],
#  'dad': ['worked..',
#   'what',
#   'did.',
#   'was',
#   'planted',
#   'standing',
#   'was',
#   'comes',
#   'said',
#   'wants',
#   'goes,',
#   'sells',
#   'a',
#   'walks',
#   'was',
#   'would',
#   'would',
#   'would'],
#  'worked..': ['I'],
#  'understood.': ['You'],
#  'do?”': ['“I', '“Job-related', '“I', 'He', '“You'],
#  'work.”': ['“Where?”', 'I'],
#  '“Where?”': ['“At'],
#  '“At': ['my'],
#  'job.”': ['“What', 'I'],
#  '“Job-related': ['work.”'],
#  'understood': ['what'],
#  'five,': ['my'],
#  'stopped': ['him'],
#  'him': ['and'],
#  'go:': ['“Dad,'],
#  '“Dad,': ['where', 'what', 'I’m', 'I'],
#  'going?”': ['He', '“Moving'],
#  'He': ['goes,',
#   'was',
#   'goes:',
#   'goes,',
#   'goes,',
#   'was..',
#   'goes,',
#   'goes,',
#   'feels',
#   'goes,',
#   'looks'],
#  '“Work.”': ['I'],
#  'work': ['at', 'at', 'with', 'on', 'for,'],
#  'chicken': ['plant.”', 'plant', 'plant', 'is,'],
#  'plant.”': ['And'],
#  'then': ['he',
#   'walk',
#   'he',
#   'a',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'it',
#   'giggle',
#   'work',
#   'I’m',
#   'I',
#   'about',
#   'when',
#   'I',
#   'when',
#   'I',
#   'I',
#   'I',
#   'when',
#   'I',
#   'I',
#   'I',
#   'she',
#   'when',
#   'I',
#   'their',
#   'they'],
#  'left.': ['You', 'And', 'Now,'],
#  'five-year-old': ['that'],
#  'plant': ['and', 'is.', 'is.'],
#  'five': ['years', 'senses'],
#  'comprehend': ['what'],
#  'is.': ['I', 'For'],
#  'is,': ['and', 'you', 'uh…'],
#  'For': ['the', 'me,'],
#  'next': ['7'],
#  '7': ['years,'],
#  'told': ['people'],
#  'planted': ['chickens.'],
#  'chickens.': ['It'],
#  'till': ['I', 'I', 'they'],
#  '12,': ['I'],
#  '“Dad..”': ['He'],
#  'exactly': ['do'],
#  'goes:': ['“I', '“Son,', 'Right?'],
#  'check': ['to'],
#  'chickens': ['are'],
#  'not.”': ['And'],
#  'meant.': ['I'],
#  'literally': ['picture', 'beg', 'the', 'pour', 'hear', 'use'],
#  'picture': ['my', 'this', 'non-white', 'brown,'],
#  'standing': ['around,', 'around', 'here..'],
#  'around,': ['going,'],
#  'going,': ['“Good', '“I', '“Hey,'],
#  '“Good': ['chicken.', 'morning,'],
#  'chicken.': ['Good', 'Stop', '“I'],
#  'Good': ['chicken.', 'solid', 'night.'],
#  'Stop': ['the', 'it!”'],
#  'line.': ['Bad'],
#  'Bad': ['chicken.”'],
#  'chicken.”': ['I'],
#  'bad': ['chicken.', 'to', 'happens'],
#  'minute.': ['Come', 'You’ll'],
#  'Come': ['here.', 'here.', 'on.', 'here.'],
#  'Listen,': ['you', 'liking'],
#  'together.': ['Okay?'],
#  'Okay?': ['Start', 'When', 'That’s'],
#  'Start': ['clucking', 'picturing'],
#  'clucking': ['like'],
#  'them.': ['Don’t', 'Do', 'Ever', 'You', 'I', 'You'],
#  'such': ['a', 'a', 'villains.', 'a'],
#  'cock.”': ['Never'],
#  'Never': ['had', 'had'],
#  'did,': ['because'],
#  'because': ['I',
#   'Macs',
#   'I’m',
#   'we’re',
#   'that’s',
#   'I',
#   'in',
#   'a',
#   'I’m',
#   'men',
#   'when',
#   'they',
#   'I'],
#  'But..': ['But', 'Um,', 'Everyone’s'],
#  'gave': ['up.', 'up', 'up', 'me'],
#  'early.': ['They'],
#  'knew..': ['They'],
#  'beg': ['me.'],
#  'They’ll': ['be'],
#  '“Son,': ['please,', 'one', 'son,', 'you’re'],
#  'please,': ['just'],
#  'try': ['and', 'calling', 'it.', 'to', 'the'],
#  '50.': ['It’s'],
#  'pass.': ['Just'],
#  '50.”': ['I’m'],
#  'bragging,': ['and..'],
#  'and..': ['Nor', 'My'],
#  'Nor': ['am'],
#  'am': ['I', 'I', 'a', 'getting'],
#  'glorifying': ['this.'],
#  'mark': ['I', 'was'],
#  'grade': ['nine'],
#  'nine': ['typing.', 'times'],
#  'typing.': ['Typing.'],
#  'Typing.': ['All'],
#  '1984.': ['Don’t'],
#  'judge': ['me.'],
#  'computers': ['yet.'],
#  'yet.': ['It'],
#  'typewriters.': ['Um,'],
#  'typing..': ['My'],
#  'final': ['mark'],
#  '13': ['percent.'],
#  'percent.': ['Even'],
#  '“Son…': ['Son,'],
#  'Son,': ['you’ve', 'oh,', 'no.', 'you', 'let'],
#  'you’ve': ['hit', 'ever', 'gotta', 'ever', 'ever', 'ever'],
#  'hit': ['a', "‘purchase.'”"],
#  'new': ['low.', 'things.', 'kid', 'one.', 'pair', 'house.', 'special,'],
#  'low.': ['Do'],
#  '25': ['percent'],
#  'percent': ['just', 'of'],
#  'signing': ['your'],
#  'name': ['correctly?', 'did', 'would', 'you', 'and', 'and', 'anyway?', 'is,'],
#  'correctly?': ['What'],
#  'put?!”': ['They'],
#  'teenager.': ['They'],
#  'only': ['rule', 'rule.', 'this', 'one', 'then,', 'live', 'other'],
#  'rule': ['when'],
#  'leave': ['the', 'immediately,”', 'America'],
#  'house': ['was..', 'in'],
#  'mall.”': ['“Okay.'],
#  '“Okay.': ['Son,', 'And', 'No', 'Russell'],
#  'die.”': ['That', 'Never'],
#  'rule.': ['“Don’t'],
#  'die.': ['We’ve'],
#  'We’ve': ['already'],
#  'failed': ['enough.'],
#  'enough.': ['We'],
#  'We': ['don’t', 'pee', 'got', 'live', 'live', 'can’t'],
#  'ultimate': ['failure.'],
#  'failure.': ['Well,'],
#  'die': ['while', 'as'],
#  'while': ['I’m', 'I’m', 'I’m'],
#  'alive.': ['After'],
#  'After': ['I'],
#  'die,': ['die'],
#  'times': ['as', 'a', 'when', 'out', 'now.'],
#  'career': ['or'],
#  'job,': ['yes,'],
#  'yes,': ['just'],
#  'profession.': ['When'],
#  '16,': ['my'],
#  'comes': ['to', 'along,', 'around'],
#  'day,': ['you', 'I’m', 'I’ll'],
#  'won’t': ['be'],
#  'school': ['anymore.”'],
#  'anymore.”': ['And'],
#  'graduate?”': ['“No,'],
#  'son.': ['Focus,', 'Focus.', 'Focus.', 'A', 'Who’s'],
#  'Focus,': ['son.', 'son.'],
#  'Focus.': ['Focus.', 'Come', 'Focus.”'],
#  'on.': ['That’s', 'You’re', 'Come', 'Let', 'Right', 'They’ve'],
#  'happen.': ['Okay?'],
#  'school,': ['you’re', 'and'],
#  '“Of': ['course,'],
#  'course,': ['I’m'],
#  'freeloader.': ['And'],
#  'anybody': ['hiring,'],
#  'hiring,': ['let'],
#  'know.”': ['He'],
#  '“Well,': ['the', 'well,', 'well,', 'you'],
#  'airport': ['is', 'was'],
#  'hiring.”': ['Here’s'],
#  'dumb': ['I', 'at'],
#  'said': ['the', '“Vince.”', 'your'],
#  'hiring': ['and'],
#  'wants': ['me', 'to'],
#  'pilot.”': ['I'],
#  '“You': ['want',
#   'take',
#   'put',
#   'put',
#   'don’t',
#   'can',
#   'don’t',
#   'know',
#   'travel?”',
#   'can'],
#  'pilot?”': ['“Oh,'],
#  'God,': ['no.'],
#  'Mylanta.': ['No,'],
#  'No,': ['no,', 'the'],
#  'no,': ['no.', 'no!”'],
#  'too': ['stupid', 'late.', 'much'],
#  'stupid': ['for', 'people.'],
#  'People’s': ['lives'],
#  'lives': ['are'],
#  'stake.”': ['“What'],
#  'airport?”': ['My'],
#  ...}

# %% [markdown]
# # Create the text generator

# %%
### import random

def generate_sentence(chain, count=10):
    '''Input a dictionary in the format of key = current word, value = list of next words
       along with the number of words you would like to see in your generated sentence.'''

    # Capitalize the first word
    word1 = random.choice(list(chain.keys()))
    sentence = word1.capitalize()

    # Generate the second word from the value list. Set the new word as the first word. Repeat.
    for i in range(count-1):
        word2 = random.choice(chain[word1])
        word1 = word2
        sentence += ' ' + word2

    # End it with a period
    sentence += '.'
    return(sentence)

# %%
generate_sentence(russell_dict)
# Out:
# 'Nickname to either of the air when you wanted to.'
